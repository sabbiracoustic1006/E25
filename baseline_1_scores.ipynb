# %% [markdown]
# # Baseline 1 Scores - No Thresholds (Raw Argmax Predictions)
# Minimal code to get baseline 1 scores from inference_threshold_refine_mean_sd_categorywise.py

# %%
import re
from pathlib import Path
from typing import Dict, List, Tuple

import pandas as pd
import numpy as np
import torch
from tqdm import tqdm
from transformers import AutoModelForTokenClassification, AutoTokenizer

from eval_score_fixed import compute_competition_score
from utils import convert_tagged_to_aspect, stratified_kfold_split

# %%
# Configuration
MODEL_DIR = Path("/data/sahmed9/E25/multi_epoch_checkpoints/deberta-v3-base/lr_1_e_neg_4/o_weight_1/o_weight_1/fold0/checkpoint-875")  # Change this
DATA_PATH = Path("data/Tagged_Titles_Train.tsv")
FOLD = 0
NUM_FOLDS = 5
SEED = 42
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

# %%
# Load data and build labels
df0 = convert_tagged_to_aspect(str(DATA_PATH))
df_split = stratified_kfold_split(df0, n_splits=NUM_FOLDS, random_state=SEED)

aspects = sorted({asp for asp in df_split["Aspect Name"].unique() if asp})
label_list = ["O"] + [f"{prefix}-{aspect}" for aspect in aspects for prefix in ("B", "I")]
label2id = {label: idx for idx, label in enumerate(label_list)}
id2label = {idx: label for label, idx in label2id.items()}

valid_df = df_split[df_split["fold"] == FOLD]
print(f"Validation samples: {len(valid_df['Record Number'].unique())}")
# Out:
# Validation samples: 1000

# %%
# Load model
tokenizer = AutoTokenizer.from_pretrained(MODEL_DIR, use_fast=True)
model = AutoModelForTokenClassification.from_pretrained(MODEL_DIR)
model.to(DEVICE)
model.eval()
print(f"Model loaded on {DEVICE}")
# Out:
# Model loaded on cuda

# %%
def extract_spans(seq: List[str], positions: List[int], offsets: List[Tuple[int, int]], text: str) -> List[Tuple[str, str]]:
    """Extract spans from token-level predictions."""
    spans = []
    idx = 0
    while idx < len(seq):
        label = seq[idx]
        if label.startswith("B-"):
            aspect = label[2:]
            start_pos = positions[idx]
            end_pos = start_pos
            idx += 1
            while idx < len(seq) and seq[idx] == f"I-{aspect}":
                end_pos = positions[idx]
                idx += 1
            start_char, _ = offsets[start_pos]
            _, end_char = offsets[end_pos]
            span_text = text[start_char:end_char].strip()
            spans.append((aspect, span_text))
        else:
            idx += 1
    return spans

# %%
# Build predictions (Baseline 1: raw argmax, no thresholds)
all_targets = []
all_preds = []

for rid in tqdm(valid_df["Record Number"].unique(), desc="Processing samples"):
    sample = valid_df[valid_df["Record Number"] == rid]
    text = sample["Title"].iat[0]
    category = str(sample["Category"].iat[0])
    gold = sample[["Category", "Aspect Name", "Aspect Value"]].values.tolist()
    
    # Tokenize
    encoded = tokenizer(text, return_tensors="pt", return_offsets_mapping=True, padding=True, truncation=True)
    offsets = encoded["offset_mapping"][0].tolist()
    
    # Create gold labels
    labels = [-100] * len(offsets)
    for cat, asp, val in gold:
        val_str = str(val)
        for match in re.finditer(re.escape(val_str), text):
            start_char, end_char = match.span()
            b_assigned = False
            for tidx, (start, end) in enumerate(offsets):
                if start >= end_char:
                    break
                if end <= start_char:
                    continue
                if not b_assigned:
                    labels[tidx] = label2id[f"B-{asp}"]
                    b_assigned = True
                else:
                    labels[tidx] = label2id[f"I-{asp}"]
    
    # Get predictions (raw argmax - no thresholds)
    encoded = {k: v.to(DEVICE) for k, v in encoded.items()}
    encoded.pop("offset_mapping")
    
    with torch.no_grad():
        logits = model(**encoded).logits
        preds = logits.argmax(dim=-1).cpu()[0].numpy()
    
    # Filter valid tokens (exclude -100)
    seq_p = []
    seq_l = []
    token_idxs = []
    for idx, l_id in enumerate(labels):
        if l_id == -100:
            continue
        seq_p.append(id2label[int(preds[idx])])
        seq_l.append(label_list[l_id])
        token_idxs.append(idx)
    
    # Extract spans
    for aspect, span in extract_spans(seq_l, token_idxs, offsets, text):
        if aspect != "O":
            all_targets.append({
                "record_id": str(rid),
                "category": category,
                "aspect_name": aspect,
                "span": span,
            })
    
    for aspect, span in extract_spans(seq_p, token_idxs, offsets, text):
        if aspect != "O":
            all_preds.append({
                "record_id": str(rid),
                "category": category,
                "aspect_name": aspect,
                "span": span,
            })
# Out:
# Processing samples:   0%|          | 0/1000 [00:00<?, ?it/s]Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Processing samples: 100%|██████████| 1000/1000 [00:15<00:00, 63.26it/s]

# %%
# Compute scores
comp = compute_competition_score(all_targets, all_preds, beta=0.2)

print("="*60)
print("Baseline 1: No thresholds (raw argmax predictions)")
print("="*60)
print(f"Overall score: {comp['overall_score']:.6f}")
print("\nPer-category scores:")
for cat, score in sorted(comp["per_category"].items()):
    print(f"  Category {cat}: {score:.6f}")
# Out:
# ============================================================
# Baseline 1: No thresholds (raw argmax predictions)
# ============================================================
# Overall score: 0.896926
#
# Per-category scores:
#   Category 1: 0.892044
#   Category 2: 0.901807

# %%
{'per_category': {'1': 0.892044481550705, '2': 0.9018074896156842},
 'overall_score': 0.8969259855831946}
# Out:
# {'per_category': {'1': 0.892044481550705, '2': 0.9018074896156842},
#  'overall_score': 0.8969259855831946}

# %%
all_targets
# Out:
# [{'record_id': '2',
#   'category': '1',
#   'aspect_name': 'Hersteller',
#   'span': 'ATE'},
#  {'record_id': '2',
#   'category': '1',
#   'aspect_name': 'Modell',
#   'span': 'Power Disc'},
#  {'record_id': '2',
#   'category': '1',
#   'aspect_name': 'Produktart',
#   'span': 'Bremsenset'},
#  {'record_id': '2',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'Mercedes'},
#  {'record_id': '2',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'SLC'},
#  {'record_id': '2',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'SLK'},
#  {'record_id': '2',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'Vorne'},
#  {'record_id': '2',
#   'category': '1',
#   'aspect_name': 'Bremsscheiben-Aussendurchmesser',
#   'span': '295MM'},
#  {'record_id': '2',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'Hinten'},
#  {'record_id': '2',
#   'category': '1',
#   'aspect_name': 'Bremsscheiben-Aussendurchmesser',
#   'span': '300MM'},
#  {'record_id': '17',
#   'category': '2',
#   'aspect_name': 'Hersteller',
#   'span': 'CONTINENTAL CTAM'},
#  {'record_id': '17',
#   'category': '2',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Wasserpumpe'},
#  {'record_id': '17',
#   'category': '2',
#   'aspect_name': 'Produktart',
#   'span': 'Zahnriemensatz'},
#  {'record_id': '17',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'OPEL'},
#  {'record_id': '29',
#   'category': '2',
#   'aspect_name': 'Hersteller',
#   'span': 'CONTITECH'},
#  {'record_id': '29',
#   'category': '2',
#   'aspect_name': 'Produktart',
#   'span': 'Zahnriemen Satz'},
#  {'record_id': '29',
#   'category': '2',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Wasserpumpe'},
#  {'record_id': '29',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'RENAULT'},
#  {'record_id': '29',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'MASTER'},
#  {'record_id': '29',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'TRAFIC'},
#  {'record_id': '29',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'LAGUNA 2.2 2.5 dCi'},
#  {'record_id': '34',
#   'category': '2',
#   'aspect_name': 'Hersteller',
#   'span': 'BOSCH'},
#  {'record_id': '34',
#   'category': '2',
#   'aspect_name': 'Herstellernummer',
#   'span': '1 987 946 344'},
#  {'record_id': '34',
#   'category': '2',
#   'aspect_name': 'Produktart',
#   'span': 'Zahnriemensatz'},
#  {'record_id': '34',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'Renault'},
#  {'record_id': '34',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Clio I II'},
#  {'record_id': '34',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Kangoo'},
#  {'record_id': '34',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Twingo 1.2'},
#  {'record_id': '41',
#   'category': '1',
#   'aspect_name': 'Hersteller',
#   'span': 'ATE'},
#  {'record_id': '41',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'BREMSSCHEIBEN'},
#  {'record_id': '41',
#   'category': '1',
#   'aspect_name': 'Bremsscheiben-Aussendurchmesser',
#   'span': 'Ø278MM'},
#  {'record_id': '41',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'BREMSBELÄGE'},
#  {'record_id': '41',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'VORNE'},
#  {'record_id': '41',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'MERCEDES-BENZ'},
#  {'record_id': '41',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'S-KLASSE SL'},
#  {'record_id': '45',
#   'category': '1',
#   'aspect_name': 'Hersteller',
#   'span': 'ATE'},
#  {'record_id': '45',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'BREMSSCHEIBEN'},
#  {'record_id': '45',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'RADLAGER'},
#  {'record_id': '45',
#   'category': '1',
#   'aspect_name': 'Bremsscheiben-Aussendurchmesser',
#   'span': 'Ø274'},
#  {'record_id': '45',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': '+BELÄGE'},
#  {'record_id': '45',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'HINTEN'},
#  {'record_id': '45',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'RENAULT'},
#  {'record_id': '45',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'LAGUNA 2'},
#  {'record_id': '45',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Jahr',
#   'span': '01-07'},
#  {'record_id': '48',
#   'category': '2',
#   'aspect_name': 'Hersteller',
#   'span': 'CONTINENTAL CTAM'},
#  {'record_id': '48',
#   'category': '2',
#   'aspect_name': 'Herstellernummer',
#   'span': 'CT1149WP1'},
#  {'record_id': '48',
#   'category': '2',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Wasserpumpe'},
#  {'record_id': '48',
#   'category': '2',
#   'aspect_name': 'Produktart',
#   'span': 'Zahnriemensatz'},
#  {'record_id': '55',
#   'category': '2',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'WASSERPUMPE,'},
#  {'record_id': '55',
#   'category': '2',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'FENSTERREINIGUNG'},
#  {'record_id': '55',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'VW'},
#  {'record_id': '55',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'MINI'},
#  {'record_id': '55',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'AAB'},
#  {'record_id': '55',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'AEU'},
#  {'record_id': '55',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'AAF'},
#  {'record_id': '55',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'AEN'},
#  {'record_id': '55',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'ACU'},
#  {'record_id': '55',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'ABL'},
#  {'record_id': '55',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': '1Y'},
#  {'record_id': '57',
#   'category': '2',
#   'aspect_name': 'Hersteller',
#   'span': 'FAI'},
#  {'record_id': '57',
#   'category': '2',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'STEUERKETTENSA'},
#  {'record_id': '57',
#   'category': '2',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'STEUERKETTEN'},
#  {'record_id': '57',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'PEUGEOT'},
#  {'record_id': '57',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': '207'},
#  {'record_id': '57',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': '308'},
#  {'record_id': '57',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'CITROEN'},
#  {'record_id': '57',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'C4'},
#  {'record_id': '57',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'C5'},
#  {'record_id': '57',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'DS3'},
#  {'record_id': '57',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'MINI'},
#  {'record_id': '57',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'R56'},
#  {'record_id': '57',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'R57'},
#  {'record_id': '70',
#   'category': '2',
#   'aspect_name': 'Hersteller',
#   'span': 'Conti CONTITECH'},
#  {'record_id': '70',
#   'category': '2',
#   'aspect_name': 'Hersteller',
#   'span': 'Conti Tech'},
#  {'record_id': '70',
#   'category': '2',
#   'aspect_name': 'Produktart',
#   'span': 'Zahnriemen-Kit'},
#  {'record_id': '70',
#   'category': '2',
#   'aspect_name': 'Herstellernummer',
#   'span': 'CT1115K1'},
#  {'record_id': '81',
#   'category': '1',
#   'aspect_name': 'Hersteller',
#   'span': 'Zimmermann'},
#  {'record_id': '81',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsscheiben'},
#  {'record_id': '81',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Beläge'},
#  {'record_id': '81',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'FORD'},
#  {'record_id': '81',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'B-Max'},
#  {'record_id': '81',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Fiesta Vi St180'},
#  {'record_id': '81',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'vorne'},
#  {'record_id': '82',
#   'category': '2',
#   'aspect_name': 'Hersteller',
#   'span': 'SKF'},
#  {'record_id': '82',
#   'category': '2',
#   'aspect_name': 'Produktart',
#   'span': 'Zahnriemensatz'},
#  {'record_id': '82',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'FORESTER'},
#  {'record_id': '82',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'IMPREZA'},
#  {'record_id': '82',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'LEGACY'},
#  {'record_id': '82',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'OUTBACK'},
#  {'record_id': '83',
#   'category': '1',
#   'aspect_name': 'Hersteller',
#   'span': 'ATE'},
#  {'record_id': '83',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsscheiben'},
#  {'record_id': '83',
#   'category': '1',
#   'aspect_name': 'Bremsscheiben-Aussendurchmesser',
#   'span': '255mm'},
#  {'record_id': '83',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsbeläge'},
#  {'record_id': '83',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'vorne'},
#  {'record_id': '83',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'Toyota'},
#  {'record_id': '83',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Corolla'},
#  {'record_id': '86',
#   'category': '1',
#   'aspect_name': 'Hersteller',
#   'span': 'EBC'},
#  {'record_id': '86',
#   'category': '1',
#   'aspect_name': 'Produktart',
#   'span': 'Bremsen Kit'},
#  {'record_id': '86',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'Vorne'},
#  {'record_id': '86',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Beläge'},
#  {'record_id': '86',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Scheiben'},
#  {'record_id': '86',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'Hyundai'},
#  {'record_id': '86',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Veloster (FS)'},
#  {'record_id': '86',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Ceed'},
#  {'record_id': '91',
#   'category': '2',
#   'aspect_name': 'Hersteller',
#   'span': 'SWAG'},
#  {'record_id': '91',
#   'category': '2',
#   'aspect_name': 'Produktart',
#   'span': 'Steuerkettensatz'},
#  {'record_id': '91',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'PEUGEOT'},
#  {'record_id': '91',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'CITROEN'},
#  {'record_id': '91',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'DS'},
#  {'record_id': '91',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': '207 Cc Sw'},
#  {'record_id': '91',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': '208 3008'},
#  {'record_id': '91',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': '308 II'},
#  {'record_id': '91',
#   'category': '2',
#   'aspect_name': 'Oe/Oem_Referenznummer(N)',
#   'span': '0816.H9'},
#  {'record_id': '92',
#   'category': '1',
#   'aspect_name': 'Hersteller',
#   'span': 'Brembo'},
#  {'record_id': '92',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsscheiben'},
#  {'record_id': '92',
#   'category': '1',
#   'aspect_name': 'Hersteller',
#   'span': 'Ate'},
#  {'record_id': '92',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'Mercedes'},
#  {'record_id': '92',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'E-Klasse W210/S210'},
#  {'record_id': '92',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'Vorne'},
#  {'record_id': '93',
#   'category': '2',
#   'aspect_name': 'Hersteller',
#   'span': 'VAICO'},
#  {'record_id': '93',
#   'category': '2',
#   'aspect_name': 'Herstellernummer',
#   'span': 'V30-10019'},
#  {'record_id': '93',
#   'category': '2',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Steuerketten'},
#  {'record_id': '93',
#   'category': '2',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Steuerkette'},
#  {'record_id': '97',
#   'category': '2',
#   'aspect_name': 'Hersteller',
#   'span': 'CONTI'},
#  {'record_id': '97',
#   'category': '2',
#   'aspect_name': 'Produktart',
#   'span': 'Zahnriemen'},
#  {'record_id': '97',
#   'category': '2',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Spannrolle'},
#  {'record_id': '97',
#   'category': '2',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Wasserpumpe'},
#  {'record_id': '97',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'SKODA'},
#  {'record_id': '97',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'OCTAVIA'},
#  {'record_id': '97',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'SEAT'},
#  {'record_id': '97',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'VW'},
#  {'record_id': '97',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'GOLF'},
#  {'record_id': '97',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'PASSAT 2.0'},
#  {'record_id': '99',
#   'category': '1',
#   'aspect_name': 'Hersteller',
#   'span': 'ATE'},
#  {'record_id': '99',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'BREMSSCHEIBEN'},
#  {'record_id': '99',
#   'category': '1',
#   'aspect_name': 'Material',
#   'span': '+CERAMIC'},
#  {'record_id': '99',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'BELÄGE+WK'},
#  {'record_id': '99',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'VORNE'},
#  {'record_id': '99',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'MERCEDES'},
#  {'record_id': '99',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'MARCO'},
#  {'record_id': '99',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'POLO'},
#  {'record_id': '99',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'VITO'},
#  {'record_id': '99',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'V-KLASSE'},
#  {'record_id': '109',
#   'category': '2',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Steuerketten'},
#  {'record_id': '109',
#   'category': '2',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Steuerkette'},
#  {'record_id': '109', 'category': '2', 'aspect_name': 'Größe', 'span': 'XXXL'},
#  {'record_id': '109',
#   'category': '2',
#   'aspect_name': 'Herstellernummer',
#   'span': '(8.9.2a)'},
#  {'record_id': '109',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'OPEL'},
#  {'record_id': '109',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Z12XE-Z14XEP'},
#  {'record_id': '109',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Jahr',
#   'span': '2007)'},
#  {'record_id': '114',
#   'category': '1',
#   'aspect_name': 'Hersteller',
#   'span': 'Textar'},
#  {'record_id': '114',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsscheiben'},
#  {'record_id': '114',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Beläge'},
#  {'record_id': '114',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'vorne'},
#  {'record_id': '114',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'TOYOTA'},
#  {'record_id': '114',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Avensis'},
#  {'record_id': '128',
#   'category': '1',
#   'aspect_name': 'Hersteller',
#   'span': 'BREMBO'},
#  {'record_id': '128',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'BREMSSCHEIBEN'},
#  {'record_id': '128',
#   'category': '1',
#   'aspect_name': 'Bremsscheiben-Aussendurchmesser',
#   'span': 'Ø'},
#  {'record_id': '128',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': '300'},
#  {'record_id': '128',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'BREMSBELÄGE'},
#  {'record_id': '128',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'VORNE'},
#  {'record_id': '128',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'BMW'},
#  {'record_id': '128',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': '3'},
#  {'record_id': '128',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Z3'},
#  {'record_id': '128',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Z4'},
#  {'record_id': '128',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'BMW'},
#  {'record_id': '130',
#   'category': '2',
#   'aspect_name': 'Produktart',
#   'span': 'Steuerkettensatz'},
#  {'record_id': '130',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'Audi'},
#  {'record_id': '130',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'A4 8HE 8ED B7 3.2L'},
#  {'record_id': '130',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'A6 4F2 4F5 C6 2.4L 3.2L'},
#  {'record_id': '130',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'A8'},
#  {'record_id': '130',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Jahr',
#   'span': '04-10'},
#  {'record_id': '134',
#   'category': '2',
#   'aspect_name': 'Hersteller',
#   'span': 'FAI AutoParts'},
#  {'record_id': '134',
#   'category': '2',
#   'aspect_name': 'Herstellernummer',
#   'span': 'TCK89L'},
#  {'record_id': '134',
#   'category': '2',
#   'aspect_name': 'Produktart',
#   'span': 'Steuerkettensatz'},
#  {'record_id': '134',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'DAIMLER'},
#  {'record_id': '134',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'JAGUAR'},
#  {'record_id': '140',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsscheiben'},
#  {'record_id': '140',
#   'category': '1',
#   'aspect_name': 'Bremsscheiben-Aussendurchmesser',
#   'span': '282,5mm'},
#  {'record_id': '140',
#   'category': '1',
#   'aspect_name': 'Bremsscheibenart',
#   'span': 'belüftet'},
#  {'record_id': '140',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsbeläge'},
#  {'record_id': '140',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'Chrysler'},
#  {'record_id': '140',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Voyager'},
#  {'record_id': '140',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Grand Voyager 3'},
#  {'record_id': '143',
#   'category': '2',
#   'aspect_name': 'Produktart',
#   'span': 'Zahnriemen'},
#  {'record_id': '143',
#   'category': '2',
#   'aspect_name': 'Hersteller',
#   'span': 'CONTI'},
#  {'record_id': '143',
#   'category': '2',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Rollen'},
#  {'record_id': '143',
#   'category': '2',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'WaPu'},
#  {'record_id': '143',
#   'category': '2',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Keilr.'},
#  {'record_id': '143',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'OPEL'},
#  {'record_id': '143',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Astra J'},
#  {'record_id': '143',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': '1,6 1,8'},
#  {'record_id': '143',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Jahr',
#   'span': '2012'},
#  {'record_id': '144',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'Peugeot'},
#  {'record_id': '144',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': '308'},
#  {'record_id': '144',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsscheiben'},
#  {'record_id': '144',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsbeläge'},
#  {'record_id': '144',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'vorne'},
#  {'record_id': '144',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'Vorderachse'},
#  {'record_id': '158',
#   'category': '2',
#   'aspect_name': 'Hersteller',
#   'span': 'FAI AutoParts'},
#  {'record_id': '158',
#   'category': '2',
#   'aspect_name': 'Herstellernummer',
#   'span': '(TCK203VVT)'},
#  {'record_id': '158',
#   'category': '2',
#   'aspect_name': 'Produktart',
#   'span': 'Steuerkettensatz'},
#  {'record_id': '158',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'HYUNDAI'},
#  {'record_id': '158',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'KIA'},
#  {'record_id': '164',
#   'category': '1',
#   'aspect_name': 'Hersteller',
#   'span': 'Febi'},
#  {'record_id': '164',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsscheiben'},
#  {'record_id': '164',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsbeläge'},
#  {'record_id': '164',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'Ford'},
#  {'record_id': '164',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Fiesta VII'},
#  {'record_id': '164',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'hinten'},
#  {'record_id': '177',
#   'category': '2',
#   'aspect_name': 'Hersteller',
#   'span': 'BOSCH'},
#  {'record_id': '177',
#   'category': '2',
#   'aspect_name': 'Produktart',
#   'span': 'Zahnriemen'},
#  {'record_id': '177',
#   'category': '2',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Spannrolle'},
#  {'record_id': '177',
#   'category': '2',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Wapu'},
#  {'record_id': '177',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Primera'},
#  {'record_id': '177',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Scenic II'},
#  {'record_id': '177',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Megane II'},
#  {'record_id': '177',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Laguna II 1.9'},
#  {'record_id': '186',
#   'category': '2',
#   'aspect_name': 'Produktart',
#   'span': 'ZAHNRIEMEN'},
#  {'record_id': '186',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'HONDA'},
#  {'record_id': '186',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'CIVIC V COUPE EJ B16A2 B16A1'},
#  {'record_id': '186',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'CRX II'},
#  {'record_id': '186',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'ED EE'},
#  {'record_id': '186',
#   'category': '2',
#   'aspect_name': 'Hersteller',
#   'span': 'CONTINENTAL'},
#  {'record_id': '190',
#   'category': '2',
#   'aspect_name': 'Hersteller',
#   'span': 'D.I.D.'},
#  {'record_id': '190',
#   'category': '2',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Steuerkettensch'},
#  {'record_id': '190',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'DR'},
#  {'record_id': '190',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': '350,'},
#  {'record_id': '190',
#   'category': '2',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Steuerketten'},
#  {'record_id': '197',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsscheiben'},
#  {'record_id': '197',
#   'category': '1',
#   'aspect_name': 'Bremsscheiben-Aussendurchmesser',
#   'span': '300'},
#  {'record_id': '197',
#   'category': '1',
#   'aspect_name': 'Bremsscheibenart',
#   'span': 'belüftet'},
#  {'record_id': '197',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsbeläge'},
#  {'record_id': '197',
#   'category': '1',
#   'aspect_name': 'Produktart',
#   'span': 'Bremsensatz'},
#  {'record_id': '197',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'vorne'},
#  {'record_id': '197',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'Ford'},
#  {'record_id': '197',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Mondeo III'},
#  {'record_id': '200',
#   'category': '1',
#   'aspect_name': 'Hersteller',
#   'span': 'Bosch'},
#  {'record_id': '200',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsscheiben'},
#  {'record_id': '200',
#   'category': '1',
#   'aspect_name': 'Bremsscheiben-Aussendurchmesser',
#   'span': '256mm'},
#  {'record_id': '200',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsbeläge'},
#  {'record_id': '200',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'vorne'},
#  {'record_id': '200',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'VW'},
#  {'record_id': '200',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Passat 35I'},
#  {'record_id': '207',
#   'category': '2',
#   'aspect_name': 'Hersteller',
#   'span': 'BOSCH'},
#  {'record_id': '207',
#   'category': '2',
#   'aspect_name': 'Produktart',
#   'span': 'Zahnriemensatz'},
#  {'record_id': '207',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'AUDI'},
#  {'record_id': '207',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'SEAT'},
#  {'record_id': '207',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'SKODA'},
#  {'record_id': '207',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'VW'},
#  {'record_id': '207',
#   'category': '2',
#   'aspect_name': 'Herstellernummer',
#   'span': '1 987 946 564'},
#  {'record_id': '208',
#   'category': '1',
#   'aspect_name': 'Hersteller',
#   'span': 'FEBI'},
#  {'record_id': '208',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'BREMSSCHEIBEN'},
#  {'record_id': '208',
#   'category': '1',
#   'aspect_name': 'Bremsscheiben-Aussendurchmesser',
#   'span': '256MM'},
#  {'record_id': '208',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'BELÄGE'},
#  {'record_id': '208',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'VORNE'},
#  {'record_id': '208',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'AUDI'},
#  {'record_id': '208',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'A3'},
#  {'record_id': '208',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'VW'},
#  {'record_id': '208',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'POLO'},
#  {'record_id': '208',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'SEAT'},
#  {'record_id': '208',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'IBIZA'},
#  {'record_id': '208',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'SKODA'},
#  {'record_id': '214',
#   'category': '1',
#   'aspect_name': 'Hersteller',
#   'span': 'Textar'},
#  {'record_id': '214',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsscheiben'},
#  {'record_id': '214',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsbeläge'},
#  {'record_id': '214',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'vorne'},
#  {'record_id': '214',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'Suzuki'},
#  {'record_id': '214',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Swift III 1,6'},
#  {'record_id': '219',
#   'category': '2',
#   'aspect_name': 'Hersteller',
#   'span': 'Conti'},
#  {'record_id': '219',
#   'category': '2',
#   'aspect_name': 'Hersteller',
#   'span': 'CONTITECH'},
#  {'record_id': '219',
#   'category': '2',
#   'aspect_name': 'Hersteller',
#   'span': 'Conti'},
#  {'record_id': '219',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Tech'},
#  {'record_id': '219',
#   'category': '2',
#   'aspect_name': 'Produktart',
#   'span': 'Zahnriemen-Kit'},
#  {'record_id': '219',
#   'category': '2',
#   'aspect_name': 'Herstellernummer',
#   'span': 'CT939K2'},
#  {'record_id': '223',
#   'category': '2',
#   'aspect_name': 'Produktart',
#   'span': 'Set'},
#  {'record_id': '223',
#   'category': '2',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Distribution'},
#  {'record_id': '223',
#   'category': '2',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Pompe'},
#  {'record_id': '223',
#   'category': '2',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Eau'},
#  {'record_id': '223',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'ALFA'},
#  {'record_id': '223',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': '159 1.9 Jtdm 16V 110KW 150CV A'},
#  {'record_id': '224',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'BREMSANLAGE'},
#  {'record_id': '224', 'category': '1', 'aspect_name': 'Stärke', 'span': '365'},
#  {'record_id': '224', 'category': '1', 'aspect_name': 'Stärke', 'span': '36'},
#  {'record_id': '224',
#   'category': '1',
#   'aspect_name': 'Maßeinheit',
#   'span': 'mm'},
#  {'record_id': '224',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'VOLKSWAGEN'},
#  {'record_id': '224',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'VW'},
#  {'record_id': '224',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'T5'},
#  {'record_id': '224',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'T6'},
#  {'record_id': '224',
#   'category': '1',
#   'aspect_name': 'Hersteller',
#   'span': 'BREMBO'},
#  {'record_id': '224',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'BREMSSATTEL'},
#  {'record_id': '231',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsscheiben'},
#  {'record_id': '231',
#   'category': '1',
#   'aspect_name': 'Bremsscheiben-Aussendurchmesser',
#   'span': '288'},
#  {'record_id': '231',
#   'category': '1',
#   'aspect_name': 'Maßeinheit',
#   'span': 'mm'},
#  {'record_id': '231',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsbeläge'},
#  {'record_id': '231',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'vorne'},
#  {'record_id': '231',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'VW'},
#  {'record_id': '231',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Caddy III'},
#  {'record_id': '234',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsscheiben'},
#  {'record_id': '234',
#   'category': '1',
#   'aspect_name': 'Produktart',
#   'span': 'Set'},
#  {'record_id': '234',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'vorne'},
#  {'record_id': '234',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremstrommel'},
#  {'record_id': '234',
#   'category': '1',
#   'aspect_name': 'Produktart',
#   'span': 'Satz'},
#  {'record_id': '234',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Zubehör'},
#  {'record_id': '234',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'hinten'},
#  {'record_id': '234',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'Opel'},
#  {'record_id': '234',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Vectra A'},
#  {'record_id': '241',
#   'category': '1',
#   'aspect_name': 'Produktart',
#   'span': 'BREMSANLAGE'},
#  {'record_id': '241',
#   'category': '1',
#   'aspect_name': 'Bremsscheiben-Aussendurchmesser',
#   'span': '347'},
#  {'record_id': '241', 'category': '1', 'aspect_name': 'Stärke', 'span': '30'},
#  {'record_id': '241',
#   'category': '1',
#   'aspect_name': 'Maßeinheit',
#   'span': 'mm'},
#  {'record_id': '241',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'AUDI'},
#  {'record_id': '241',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'S2 20V TURBO 3B'},
#  {'record_id': '241',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'ABY'},
#  {'record_id': '241',
#   'category': '1',
#   'aspect_name': 'Hersteller',
#   'span': 'BREMBO'},
#  {'record_id': '241',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'BREMSSATTEL'},
#  {'record_id': '254',
#   'category': '1',
#   'aspect_name': 'Hersteller',
#   'span': 'ZIMMERMANN'},
#  {'record_id': '254',
#   'category': '1',
#   'aspect_name': 'Produktlinie',
#   'span': 'SPORT'},
#  {'record_id': '254',
#   'category': '1',
#   'aspect_name': 'Produktart',
#   'span': 'BREMSE BREMSEN'},
#  {'record_id': '254',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'BREMSSCHEIBEN'},
#  {'record_id': '254',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'VORNE HINTEN'},
#  {'record_id': '254',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'BMW'},
#  {'record_id': '254',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'X5 E53 3.0 d'},
#  {'record_id': '255',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'Skoda'},
#  {'record_id': '255',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Octavia [1U]'},
#  {'record_id': '255',
#   'category': '1',
#   'aspect_name': 'Hersteller',
#   'span': 'Metzger'},
#  {'record_id': '255',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsscheiben'},
#  {'record_id': '255',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsbeläge'},
#  {'record_id': '255',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Warnkabel'},
#  {'record_id': '255',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'vorne'},
#  {'record_id': '257',
#   'category': '2',
#   'aspect_name': 'Hersteller',
#   'span': 'CONTI'},
#  {'record_id': '257',
#   'category': '2',
#   'aspect_name': 'Produktart',
#   'span': 'ZAHNRIEMENSATZ'},
#  {'record_id': '257',
#   'category': '2',
#   'aspect_name': 'Herstellernummer',
#   'span': 'CT989K1'},
#  {'record_id': '257',
#   'category': '2',
#   'aspect_name': 'Produktart',
#   'span': '(ZAHNRIEMEN'},
#  {'record_id': '257',
#   'category': '2',
#   'aspect_name': 'Anzahl_Der_Einheiten',
#   'span': '2'},
#  {'record_id': '257',
#   'category': '2',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'SPANNROLLEN)'},
#  {'record_id': '271',
#   'category': '1',
#   'aspect_name': 'Hersteller',
#   'span': 'Zimmermann'},
#  {'record_id': '271',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsscheiben'},
#  {'record_id': '271',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Beläge'},
#  {'record_id': '271',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'FORD'},
#  {'record_id': '271',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Galaxy'},
#  {'record_id': '271',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'VW'},
#  {'record_id': '271',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Sharan'},
#  {'record_id': '271',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'vorne'},
#  {'record_id': '271',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'hinten'},
#  {'record_id': '275',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'Peugeot'},
#  {'record_id': '275',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Boxer'},
#  {'record_id': '275',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsscheiben'},
#  {'record_id': '275',
#   'category': '1',
#   'aspect_name': 'Produktart',
#   'span': 'Bremsen'},
#  {'record_id': '275',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsbeläge'},
#  {'record_id': '275',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'vorne hinten'},
#  {'record_id': '276',
#   'category': '2',
#   'aspect_name': 'Hersteller',
#   'span': 'SNR'},
#  {'record_id': '276',
#   'category': '2',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Water Pump'},
#  {'record_id': '276',
#   'category': '2',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': '&amp;'},
#  {'record_id': '276',
#   'category': '2',
#   'aspect_name': 'Produktart',
#   'span': 'Timing Belt Set'},
#  {'record_id': '276',
#   'category': '2',
#   'aspect_name': 'Herstellernummer',
#   'span': 'KDP457.540'},
#  {'record_id': '277',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsscheiben'},
#  {'record_id': '277',
#   'category': '1',
#   'aspect_name': 'Bremsscheiben-Aussendurchmesser',
#   'span': '257'},
#  {'record_id': '277',
#   'category': '1',
#   'aspect_name': 'Maßeinheit',
#   'span': 'mm'},
#  {'record_id': '277',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsbeläge'},
#  {'record_id': '277',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'vorne'},
#  {'record_id': '277',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'Opel'},
#  {'record_id': '277',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Corsa D'},
#  {'record_id': '282',
#   'category': '2',
#   'aspect_name': 'Hersteller',
#   'span': 'CONTI'},
#  {'record_id': '282',
#   'category': '2',
#   'aspect_name': 'Produktart',
#   'span': 'Zahnriemen'},
#  {'record_id': '282',
#   'category': '2',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Rollen'},
#  {'record_id': '282',
#   'category': '2',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Wasserpumpe'},
#  {'record_id': '282',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'SKODA'},
#  {'record_id': '282',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Octavia'},
#  {'record_id': '282',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Fabia'},
#  {'record_id': '282',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Roomster'},
#  {'record_id': '282',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Superb 1.9TDI'},
#  {'record_id': '283',
#   'category': '1',
#   'aspect_name': 'Hersteller',
#   'span': 'Textar'},
#  {'record_id': '283',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsscheiben'},
#  {'record_id': '283',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsbeläge'},
#  {'record_id': '283',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'Ford'},
#  {'record_id': '283',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Transit'},
#  {'record_id': '283',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'vorne'},
#  {'record_id': '294',
#   'category': '1',
#   'aspect_name': 'Hersteller',
#   'span': 'BREMBO'},
#  {'record_id': '294',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsenset'},
#  {'record_id': '294',
#   'category': '1',
#   'aspect_name': 'Bremsscheibenart',
#   'span': 'gelocht'},
#  {'record_id': '294',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'BMW'},
#  {'record_id': '294',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': '3er (E36)(E46)'},
#  {'record_id': '294',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Z3'},
#  {'record_id': '294',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Z4 (E85)'},
#  {'record_id': '294',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'Vorne'},
#  {'record_id': '294',
#   'category': '1',
#   'aspect_name': 'Bremsscheiben-Aussendurchmesser',
#   'span': '286MM'},
#  {'record_id': '298',
#   'category': '2',
#   'aspect_name': 'Hersteller',
#   'span': 'CONTITECH'},
#  {'record_id': '298',
#   'category': '2',
#   'aspect_name': 'Herstellernummer',
#   'span': 'CT718WP1'},
#  {'record_id': '298',
#   'category': '2',
#   'aspect_name': 'Produktart',
#   'span': 'Zahnriemensatz'},
#  {'record_id': '298',
#   'category': '2',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'WAPU'},
#  {'record_id': '298',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'PEUGEOT'},
#  {'record_id': '298',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'CITROËN'},
#  {'record_id': '317',
#   'category': '2',
#   'aspect_name': 'Produktart',
#   'span': 'Zahnriemen'},
#  {'record_id': '317',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'SEAT'},
#  {'record_id': '317',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'SKODA'},
#  {'record_id': '321',
#   'category': '1',
#   'aspect_name': 'Hersteller',
#   'span': 'ATE'},
#  {'record_id': '321',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'BREMSSCHEIBEN'},
#  {'record_id': '321',
#   'category': '1',
#   'aspect_name': 'Bremsscheiben-Aussendurchmesser',
#   'span': 'Ø294'},
#  {'record_id': '321',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': '+BELÄGE'},
#  {'record_id': '321',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': '+VWK'},
#  {'record_id': '321',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': '+HANDBREMSBACKEN'},
#  {'record_id': '321',
#   'category': '1',
#   'aspect_name': 'Produktart',
#   'span': 'SET'},
#  {'record_id': '321',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'HINTEN'},
#  {'record_id': '321',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'BMW'},
#  {'record_id': '321',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': '3-ER E46'},
#  {'record_id': '325',
#   'category': '1',
#   'aspect_name': 'Hersteller',
#   'span': 'Ate'},
#  {'record_id': '325',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsscheiben'},
#  {'record_id': '325',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsbeläge'},
#  {'record_id': '325',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'Fiat'},
#  {'record_id': '325',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Grande Punto'},
#  {'record_id': '325',
#   'category': '1',
#   'aspect_name': 'Produktart',
#   'span': 'Satz'},
#  {'record_id': '325',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'hinten'},
#  {'record_id': '328',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'OPEL'},
#  {'record_id': '328',
#   'category': '2',
#   'aspect_name': 'Produktart',
#   'span': 'Zahnriemensatz'},
#  {'record_id': '328',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Astra'},
#  {'record_id': '328',
#   'category': '2',
#   'aspect_name': 'Herstellernummer',
#   'span': '95516740'},
#  {'record_id': '331',
#   'category': '2',
#   'aspect_name': 'Produktart',
#   'span': 'ZAHNRIEMENSATZ'},
#  {'record_id': '331',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'CHRYSLER'},
#  {'record_id': '331',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'PT'},
#  {'record_id': '331',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'CRUISER PT ECC PT'},
#  {'record_id': '331',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'CRUISER'},
#  {'record_id': '331',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'KOMBI PT'},
#  {'record_id': '331',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'NEON PL'},
#  {'record_id': '340',
#   'category': '2',
#   'aspect_name': 'Hersteller',
#   'span': 'FEBI BILSTEIN'},
#  {'record_id': '340',
#   'category': '2',
#   'aspect_name': 'Herstellernummer',
#   'span': '47700'},
#  {'record_id': '340',
#   'category': '2',
#   'aspect_name': 'Produktart',
#   'span': 'Timing Chain Kit'},
#  {'record_id': '340',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'PORSCHE'},
#  {'record_id': '343',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'Toyota'},
#  {'record_id': '343',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Yaris Verso'},
#  {'record_id': '343',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsscheiben'},
#  {'record_id': '343',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Beläge'},
#  {'record_id': '343',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'vorne'},
#  {'record_id': '343',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'hinten'},
#  {'record_id': '345',
#   'category': '2',
#   'aspect_name': 'Produktart',
#   'span': 'ZAHNRIEMENSATZ'},
#  {'record_id': '345',
#   'category': '2',
#   'aspect_name': 'Produktart',
#   'span': 'ZAHNRIEMEN'},
#  {'record_id': '345',
#   'category': '2',
#   'aspect_name': 'Produktart',
#   'span': 'ZAHNRIEMENSET'},
#  {'record_id': '345',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'KIA'},
#  {'record_id': '345',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'PICANTO SA 1.0 1.1'},
#  {'record_id': '345',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Jahr',
#   'span': '04'},
#  {'record_id': '348',
#   'category': '2',
#   'aspect_name': 'Produktart',
#   'span': 'Steuerkettensatz'},
#  {'record_id': '348',
#   'category': '2',
#   'aspect_name': 'Anwendung',
#   'span': 'Kurbelwelle'},
#  {'record_id': '348',
#   'category': '2',
#   'aspect_name': 'Anwendung',
#   'span': 'Nockenwelle'},
#  {'record_id': '348',
#   'category': '2',
#   'aspect_name': 'Einbauposition',
#   'span': 'beidseitig'},
#  {'record_id': '348',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'VW'},
#  {'record_id': '348',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'Audi'},
#  {'record_id': '348',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'Skoda'},
#  {'record_id': '351',
#   'category': '1',
#   'aspect_name': 'Hersteller',
#   'span': 'ZIMMERMANN'},
#  {'record_id': '351',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Scheibenbremse'},
#  {'record_id': '351',
#   'category': '1',
#   'aspect_name': 'Produktart',
#   'span': 'Bremsensatz'},
#  {'record_id': '351',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'Hinten'},
#  {'record_id': '351',
#   'category': '1',
#   'aspect_name': 'Oe/Oem_Referenznummer(N)',
#   'span': '640.4245.00'},
#  {'record_id': '351',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'Opel'},
#  {'record_id': '351',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Astra'},
#  {'record_id': '352',
#   'category': '2',
#   'aspect_name': 'Hersteller',
#   'span': 'HEPU'},
#  {'record_id': '352',
# ...
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'VORNE'},
#  {'record_id': '565',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'MERCEDES-BENZ'},
#  {'record_id': '565',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'T1 T2/LN1 T1/TN'},
#  {'record_id': '566',
#   'category': '2',
#   'aspect_name': 'Hersteller',
#   'span': 'CONTI'},
#  {'record_id': '566',
#   'category': '2',
#   'aspect_name': 'Produktart',
#   'span': 'Zahnriemen Satz'},
#  {'record_id': '566',
#   'category': '2',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Wasserpumpe'},
#  {'record_id': '566',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'BMW'},
#  {'record_id': '566',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'E30 316'},
#  {'record_id': '566',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': '318'},
#  {'record_id': '566',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'E34 518'},
#  {'record_id': '566',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': '100'},
#  {'record_id': '566',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': '102'},
#  {'record_id': '566',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': '113'},
#  {'record_id': '566',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': '115 PS'},
#  {'record_id': '569',
#   'category': '2',
#   'aspect_name': 'Hersteller',
#   'span': 'CONTI'},
#  {'record_id': '569',
#   'category': '2',
#   'aspect_name': 'Produktart',
#   'span': 'ZAHNRIEMEN'},
#  {'record_id': '569',
#   'category': '2',
#   'aspect_name': 'Herstellernummer',
#   'span': 'CT'},
#  {'record_id': '569',
#   'category': '2',
#   'aspect_name': 'Oe/Oem_Referenznummer(N)',
#   'span': '957'},
#  {'record_id': '569',
#   'category': '2',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'ROLLENSATZ'},
#  {'record_id': '569',
#   'category': '2',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'WASSERPUMPE'},
#  {'record_id': '569',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'VW'},
#  {'record_id': '569',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'GOLF'},
#  {'record_id': '569',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'IV'},
#  {'record_id': '569',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'V'},
#  {'record_id': '569',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'POLO 1.4 16V'},
#  {'record_id': '576',
#   'category': '2',
#   'aspect_name': 'Hersteller',
#   'span': 'Conti'},
#  {'record_id': '576',
#   'category': '2',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Wasserpumpe'},
#  {'record_id': '576',
#   'category': '2',
#   'aspect_name': 'Produktart',
#   'span': 'Zahnriemensatz'},
#  {'record_id': '576', 'category': '2', 'aspect_name': 'Menge', 'span': '5L'},
#  {'record_id': '576',
#   'category': '2',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Frostschutz'},
#  {'record_id': '576',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'Peugeot'},
#  {'record_id': '576',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'Citroen'},
#  {'record_id': '576',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': '1.6 16 V'},
#  {'record_id': '581',
#   'category': '2',
#   'aspect_name': 'Hersteller',
#   'span': 'CONTITECH'},
#  {'record_id': '581',
#   'category': '2',
#   'aspect_name': 'Produktart',
#   'span': 'ZAHNRIEMEN-SATZ SET'},
#  {'record_id': '581',
#   'category': '2',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': '+WASSERPUMPE'},
#  {'record_id': '581',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'RENAULT'},
#  {'record_id': '581',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'MASTER 2'},
#  {'record_id': '581',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': '2.2'},
#  {'record_id': '581',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': '2.5 dCi'},
#  {'record_id': '581',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': '00-'},
#  {'record_id': '590',
#   'category': '2',
#   'aspect_name': 'Hersteller',
#   'span': 'INA'},
#  {'record_id': '590',
#   'category': '2',
#   'aspect_name': 'Produktart',
#   'span': 'Zahnriemensatz'},
#  {'record_id': '590',
#   'category': '2',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Thermostat'},
#  {'record_id': '590',
#   'category': '2',
#   'aspect_name': 'Hersteller',
#   'span': 'CONTI'},
#  {'record_id': '590',
#   'category': '2',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Keilriemen'},
#  {'record_id': '590',
#   'category': '2',
#   'aspect_name': 'Hersteller',
#   'span': 'INA'},
#  {'record_id': '590',
#   'category': '2',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Rollen'},
#  {'record_id': '590',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'Audi'},
#  {'record_id': '590',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'VW'},
#  {'record_id': '590',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': '2.5'},
#  {'record_id': '594',
#   'category': '1',
#   'aspect_name': 'Hersteller',
#   'span': 'ATE'},
#  {'record_id': '594',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsscheiben'},
#  {'record_id': '594',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Beläge'},
#  {'record_id': '594',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'Vorne'},
#  {'record_id': '594',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'Hinten'},
#  {'record_id': '594',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'Audi'},
#  {'record_id': '594',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'Seat'},
#  {'record_id': '594',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'Skoda'},
#  {'record_id': '594',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'VW'},
#  {'record_id': '594',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'Cupra'},
#  {'record_id': '598',
#   'category': '1',
#   'aspect_name': 'Hersteller',
#   'span': 'Bosch'},
#  {'record_id': '598',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsscheiben'},
#  {'record_id': '598',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'vorne'},
#  {'record_id': '598',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'MERCEDES'},
#  {'record_id': '598',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'A-Klasse'},
#  {'record_id': '598',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'W168'},
#  {'record_id': '601',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'Peugeot'},
#  {'record_id': '601',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': '308'},
#  {'record_id': '601',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsscheiben'},
#  {'record_id': '601',
#   'category': '1',
#   'aspect_name': 'Besonderheiten',
#   'span': 'ABS'},
#  {'record_id': '601',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Ringe Radlager'},
#  {'record_id': '601',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsbeläge'},
#  {'record_id': '601',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'hinten'},
#  {'record_id': '604',
#   'category': '1',
#   'aspect_name': 'Hersteller',
#   'span': 'BREMBO'},
#  {'record_id': '604',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'BREMSSCHEIBEN'},
#  {'record_id': '604',
#   'category': '1',
#   'aspect_name': 'Bremsscheiben-Aussendurchmesser',
#   'span': '280mm'},
#  {'record_id': '604',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'BELÄGE'},
#  {'record_id': '604',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'HINTEN'},
#  {'record_id': '604',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'BMW'},
#  {'record_id': '604',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': '1er E81'},
#  {'record_id': '604',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'E87'},
#  {'record_id': '620',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'Seat'},
#  {'record_id': '620',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'Skoda'},
#  {'record_id': '620',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'VW'},
#  {'record_id': '620',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': '1.8 TSI TFSI CDH CDAA'},
#  {'record_id': '620',
#   'category': '2',
#   'aspect_name': 'Produktart',
#   'span': 'Steuerkettensatz'},
#  {'record_id': '620',
#   'category': '2',
#   'aspect_name': 'Herstellernummer',
#   'span': '06H109158H'},
#  {'record_id': '620',
#   'category': '2',
#   'aspect_name': 'Hersteller',
#   'span': 'FEBI'},
#  {'record_id': '620',
#   'category': '2',
#   'aspect_name': 'Herstellernummer',
#   'span': '45955'},
#  {'record_id': '620',
#   'category': '2',
#   'aspect_name': 'Herstellernummer',
#   'span': '45956'},
#  {'record_id': '623',
#   'category': '2',
#   'aspect_name': 'Hersteller',
#   'span': 'SWAG'},
#  {'record_id': '623',
#   'category': '2',
#   'aspect_name': 'Produktart',
#   'span': 'Steuerkettensatz Beidseitig'},
#  {'record_id': '623',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'AUDI,'},
#  {'record_id': '623',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'SKODA,'},
#  {'record_id': '623',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'VW'},
#  {'record_id': '626',
#   'category': '1',
#   'aspect_name': 'Hersteller',
#   'span': 'Textar'},
#  {'record_id': '626',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsscheiben'},
#  {'record_id': '626',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Beläge'},
#  {'record_id': '626',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'Vorn'},
#  {'record_id': '626',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'BMW'},
#  {'record_id': '626',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': '7Er E38'},
#  {'record_id': '626',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': '740I'},
#  {'record_id': '626',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': '740Il'},
#  {'record_id': '628',
#   'category': '1',
#   'aspect_name': 'Hersteller',
#   'span': 'BREMBO'},
#  {'record_id': '628',
#   'category': '1',
#   'aspect_name': 'Produktart',
#   'span': 'Bremsenset'},
#  {'record_id': '628',
#   'category': '1',
#   'aspect_name': 'Bremsscheibenart',
#   'span': 'gelocht'},
#  {'record_id': '628',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'VW'},
#  {'record_id': '628',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Passat'},
#  {'record_id': '628',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Scirocco'},
#  {'record_id': '628',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Tiguan'},
#  {'record_id': '628',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'Hinten'},
#  {'record_id': '628',
#   'category': '1',
#   'aspect_name': 'Bremsscheiben-Aussendurchmesser',
#   'span': '310MM'},
#  {'record_id': '631',
#   'category': '1',
#   'aspect_name': 'Hersteller',
#   'span': 'ATE'},
#  {'record_id': '631',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsscheiben'},
#  {'record_id': '631',
#   'category': '1',
#   'aspect_name': 'Bremsscheiben-Aussendurchmesser',
#   'span': '240Mm'},
#  {'record_id': '631',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'vorne'},
#  {'record_id': '631',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'Ford'},
#  {'record_id': '631',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Fiesta Mk4 Iv'},
#  {'record_id': '631',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Ka'},
#  {'record_id': '631',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Courier'},
#  {'record_id': '634',
#   'category': '1',
#   'aspect_name': 'Hersteller',
#   'span': 'FEBI'},
#  {'record_id': '634',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsscheiben'},
#  {'record_id': '634',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsbeläge'},
#  {'record_id': '634',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Wkt.'},
#  {'record_id': '634',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'Mini'},
#  {'record_id': '634',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'R50/52/R53'},
#  {'record_id': '634',
#   'category': '1',
#   'aspect_name': 'Produktart',
#   'span': 'Satz'},
#  {'record_id': '634',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'Vorne'},
#  {'record_id': '635',
#   'category': '1',
#   'aspect_name': 'Hersteller',
#   'span': 'EBC'},
#  {'record_id': '635',
#   'category': '1',
#   'aspect_name': 'Bremsscheibenart',
#   'span': 'B12'},
#  {'record_id': '635',
#   'category': '1',
#   'aspect_name': 'Produktart',
#   'span': 'Bremsen Kit'},
#  {'record_id': '635',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'Vorne'},
#  {'record_id': '635',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Beläge'},
#  {'record_id': '635',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Scheiben'},
#  {'record_id': '635',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'Audi'},
#  {'record_id': '635',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'A6'},
#  {'record_id': '635',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': '(4G5, C7, 4GD)'},
#  {'record_id': '635',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'A7'},
#  {'record_id': '635',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Q5'},
#  {'record_id': '636',
#   'category': '2',
#   'aspect_name': 'Produktart',
#   'span': 'ZAHNRIEMEN'},
#  {'record_id': '636',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'CITROËN'},
#  {'record_id': '636',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'PEUGEOT'},
#  {'record_id': '636',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'C5 II RC 9HZ 9HY'},
#  {'record_id': '636',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'C5 II BREAK RE'},
#  {'record_id': '636',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'C3'},
#  {'record_id': '636',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'PICASSO'},
#  {'record_id': '640',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsscheiben'},
#  {'record_id': '640',
#   'category': '1',
#   'aspect_name': 'Bremsscheiben-Aussendurchmesser',
#   'span': '288'},
#  {'record_id': '640',
#   'category': '1',
#   'aspect_name': 'Maßeinheit',
#   'span': 'mm'},
#  {'record_id': '640',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsbeläge'},
#  {'record_id': '640',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'vorne'},
#  ...]

# %%
all_preds
# Out:
# [{'record_id': '2',
#   'category': '1',
#   'aspect_name': 'Hersteller',
#   'span': 'ATE'},
#  {'record_id': '2',
#   'category': '1',
#   'aspect_name': 'Modell',
#   'span': 'Power Disc'},
#  {'record_id': '2',
#   'category': '1',
#   'aspect_name': 'Produktart',
#   'span': 'Bremsenset'},
#  {'record_id': '2',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'Mercedes'},
#  {'record_id': '2',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'SLC'},
#  {'record_id': '2',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'SLK'},
#  {'record_id': '2',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'Vorne'},
#  {'record_id': '2',
#   'category': '1',
#   'aspect_name': 'Bremsscheiben-Aussendurchmesser',
#   'span': '295MM'},
#  {'record_id': '2',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'Hinten'},
#  {'record_id': '2',
#   'category': '1',
#   'aspect_name': 'Bremsscheiben-Aussendurchmesser',
#   'span': '300MM'},
#  {'record_id': '17',
#   'category': '2',
#   'aspect_name': 'Hersteller',
#   'span': 'CONTINENTAL CTAM'},
#  {'record_id': '17',
#   'category': '2',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Wasserpumpe'},
#  {'record_id': '17',
#   'category': '2',
#   'aspect_name': 'Produktart',
#   'span': 'Zahnriemensatz'},
#  {'record_id': '17',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'OPEL'},
#  {'record_id': '29',
#   'category': '2',
#   'aspect_name': 'Hersteller',
#   'span': 'CONTITECH'},
#  {'record_id': '29',
#   'category': '2',
#   'aspect_name': 'Produktart',
#   'span': 'Zahnriemen Satz'},
#  {'record_id': '29',
#   'category': '2',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Wasserpumpe'},
#  {'record_id': '29',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'RENAULT'},
#  {'record_id': '29',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'MASTER'},
#  {'record_id': '29',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'TRAFIC'},
#  {'record_id': '29',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'LAGUNA 2.2 2.5 dCi'},
#  {'record_id': '34',
#   'category': '2',
#   'aspect_name': 'Hersteller',
#   'span': 'BOSCH'},
#  {'record_id': '34',
#   'category': '2',
#   'aspect_name': 'Herstellernummer',
#   'span': '1 987 946 344'},
#  {'record_id': '34',
#   'category': '2',
#   'aspect_name': 'Produktart',
#   'span': 'Zahnriemensatz'},
#  {'record_id': '34',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'Renault'},
#  {'record_id': '34',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Clio I II'},
#  {'record_id': '34',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Kangoo'},
#  {'record_id': '34',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Twingo 1.2'},
#  {'record_id': '41',
#   'category': '1',
#   'aspect_name': 'Hersteller',
#   'span': 'ATE'},
#  {'record_id': '41',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'BREMSSCHEIBEN'},
#  {'record_id': '41',
#   'category': '1',
#   'aspect_name': 'Bremsscheiben-Aussendurchmesser',
#   'span': 'Ø278MM'},
#  {'record_id': '41',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'BREMSBELÄGE'},
#  {'record_id': '41',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'VORNE'},
#  {'record_id': '41',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'MERCEDES-BENZ'},
#  {'record_id': '41',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'S-KLASSE SL'},
#  {'record_id': '45',
#   'category': '1',
#   'aspect_name': 'Hersteller',
#   'span': 'ATE'},
#  {'record_id': '45',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'BREMSSCHEIBEN'},
#  {'record_id': '45',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'RADLAGER'},
#  {'record_id': '45',
#   'category': '1',
#   'aspect_name': 'Bremsscheiben-Aussendurchmesser',
#   'span': 'Ø274'},
#  {'record_id': '45',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': '+BELÄGE'},
#  {'record_id': '45',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'HINTEN'},
#  {'record_id': '45',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'RENAULT'},
#  {'record_id': '45',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'LAGUNA 2'},
#  {'record_id': '45',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Jahr',
#   'span': '01-07'},
#  {'record_id': '48',
#   'category': '2',
#   'aspect_name': 'Hersteller',
#   'span': 'CONTINENTAL CTAM'},
#  {'record_id': '48',
#   'category': '2',
#   'aspect_name': 'Herstellernummer',
#   'span': 'CT1149WP1'},
#  {'record_id': '48',
#   'category': '2',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Wasserpumpe'},
#  {'record_id': '48',
#   'category': '2',
#   'aspect_name': 'Produktart',
#   'span': 'Zahnriemensatz'},
#  {'record_id': '55',
#   'category': '2',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'WASSERPUMPE,'},
#  {'record_id': '55',
#   'category': '2',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'FENSTERREINIGUNG'},
#  {'record_id': '55',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'VW'},
#  {'record_id': '55',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'MINI'},
#  {'record_id': '57',
#   'category': '2',
#   'aspect_name': 'Hersteller',
#   'span': 'FAI'},
#  {'record_id': '57',
#   'category': '2',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'STEUERKETTEN'},
#  {'record_id': '57',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'PEUGEOT'},
#  {'record_id': '57',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': '207'},
#  {'record_id': '57',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': '308'},
#  {'record_id': '57',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'CITROEN'},
#  {'record_id': '57',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'C4'},
#  {'record_id': '57',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'MINI'},
#  {'record_id': '57',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'R56'},
#  {'record_id': '57',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'R57'},
#  {'record_id': '70',
#   'category': '2',
#   'aspect_name': 'Hersteller',
#   'span': 'Conti CONTITECH'},
#  {'record_id': '70',
#   'category': '2',
#   'aspect_name': 'Hersteller',
#   'span': 'Conti Tech'},
#  {'record_id': '70',
#   'category': '2',
#   'aspect_name': 'Produktart',
#   'span': 'Zahnriemen-Kit'},
#  {'record_id': '70',
#   'category': '2',
#   'aspect_name': 'Herstellernummer',
#   'span': 'CT1115K1'},
#  {'record_id': '81',
#   'category': '1',
#   'aspect_name': 'Hersteller',
#   'span': 'Zimmermann'},
#  {'record_id': '81',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsscheiben'},
#  {'record_id': '81',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Beläge'},
#  {'record_id': '81',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'FORD'},
#  {'record_id': '81',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'B-Max'},
#  {'record_id': '81',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Fiesta Vi St180'},
#  {'record_id': '81',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'vorne'},
#  {'record_id': '82',
#   'category': '2',
#   'aspect_name': 'Hersteller',
#   'span': 'SKF'},
#  {'record_id': '82',
#   'category': '2',
#   'aspect_name': 'Produktart',
#   'span': 'Zahnriemensatz'},
#  {'record_id': '82',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'FORESTER'},
#  {'record_id': '82',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'IMPREZA'},
#  {'record_id': '83',
#   'category': '1',
#   'aspect_name': 'Hersteller',
#   'span': 'ATE'},
#  {'record_id': '83',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsscheiben'},
#  {'record_id': '83',
#   'category': '1',
#   'aspect_name': 'Bremsscheiben-Aussendurchmesser',
#   'span': '255mm'},
#  {'record_id': '83',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsbeläge'},
#  {'record_id': '83',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'vorne'},
#  {'record_id': '83',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'Toyota'},
#  {'record_id': '83',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Corolla'},
#  {'record_id': '86',
#   'category': '1',
#   'aspect_name': 'Hersteller',
#   'span': 'EBC'},
#  {'record_id': '86', 'category': '1', 'aspect_name': 'Modell', 'span': 'B01'},
#  {'record_id': '86',
#   'category': '1',
#   'aspect_name': 'Produktart',
#   'span': 'Bremsen Kit'},
#  {'record_id': '86',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'Vorne'},
#  {'record_id': '86',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Beläge'},
#  {'record_id': '86',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Scheiben'},
#  {'record_id': '86',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'Hyundai'},
#  {'record_id': '86',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Ce'},
#  {'record_id': '91',
#   'category': '2',
#   'aspect_name': 'Hersteller',
#   'span': 'SWAG'},
#  {'record_id': '91',
#   'category': '2',
#   'aspect_name': 'Produktart',
#   'span': 'Steuerkettensatz'},
#  {'record_id': '91',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'PEUGEOT'},
#  {'record_id': '91',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'CITROEN'},
#  {'record_id': '91',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': '207'},
#  {'record_id': '91',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': '208'},
#  {'record_id': '91',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': '3008'},
#  {'record_id': '92',
#   'category': '1',
#   'aspect_name': 'Hersteller',
#   'span': 'Brembo'},
#  {'record_id': '92',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsscheiben'},
#  {'record_id': '92',
#   'category': '1',
#   'aspect_name': 'Hersteller',
#   'span': 'Ate'},
#  {'record_id': '92',
#   'category': '1',
#   'aspect_name': 'SAE_Viskosität',
#   'span': 'Ceramic'},
#  {'record_id': '92',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'Mercedes'},
#  {'record_id': '92',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'Vorne'},
#  {'record_id': '93',
#   'category': '2',
#   'aspect_name': 'Hersteller',
#   'span': 'VAICO'},
#  {'record_id': '93',
#   'category': '2',
#   'aspect_name': 'Herstellernummer',
#   'span': 'V30-10019'},
#  {'record_id': '93',
#   'category': '2',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Steuerkette'},
#  {'record_id': '97',
#   'category': '2',
#   'aspect_name': 'Hersteller',
#   'span': 'CONTI'},
#  {'record_id': '97',
#   'category': '2',
#   'aspect_name': 'Produktart',
#   'span': 'Zahnriemen'},
#  {'record_id': '97',
#   'category': '2',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Spannrolle'},
#  {'record_id': '97',
#   'category': '2',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Wasserpumpe'},
#  {'record_id': '97',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'SKODA'},
#  {'record_id': '97',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'OCTAVIA'},
#  {'record_id': '97',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'SEAT'},
#  {'record_id': '97',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'VW'},
#  {'record_id': '97',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'GOLF'},
#  {'record_id': '97',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'PASSAT 2.0'},
#  {'record_id': '99',
#   'category': '1',
#   'aspect_name': 'Hersteller',
#   'span': 'ATE'},
#  {'record_id': '99',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'BREMSSCHEIBEN'},
#  {'record_id': '99',
#   'category': '1',
#   'aspect_name': 'Material',
#   'span': '+CERAMIC'},
#  {'record_id': '99',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'BELÄGE+WK'},
#  {'record_id': '99',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'VORNE'},
#  {'record_id': '99',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'MERCEDES'},
#  {'record_id': '99',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'MARCO'},
#  {'record_id': '99',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'POLO'},
#  {'record_id': '99',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'VITO'},
#  {'record_id': '99',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'V-KLASSE'},
#  {'record_id': '109',
#   'category': '2',
#   'aspect_name': 'Produktart',
#   'span': 'Satz'},
#  {'record_id': '109',
#   'category': '2',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Steuerkette'},
#  {'record_id': '109',
#   'category': '2',
#   'aspect_name': 'Herstellernummer',
#   'span': '(8.9.2a)'},
#  {'record_id': '109',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'OPEL'},
#  {'record_id': '109',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Z12XE-Z14XEP'},
#  {'record_id': '109',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Jahr',
#   'span': '2007)'},
#  {'record_id': '114',
#   'category': '1',
#   'aspect_name': 'Hersteller',
#   'span': 'Textar'},
#  {'record_id': '114',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsscheiben'},
#  {'record_id': '114',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Beläge'},
#  {'record_id': '114',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'vorne'},
#  {'record_id': '114',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'TOYOTA'},
#  {'record_id': '114',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Avensis'},
#  {'record_id': '128',
#   'category': '1',
#   'aspect_name': 'Hersteller',
#   'span': 'BREMBO'},
#  {'record_id': '128',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'BREMSSCHEIBEN'},
#  {'record_id': '128',
#   'category': '1',
#   'aspect_name': 'Bremsscheiben-Aussendurchmesser',
#   'span': 'Ø300MM'},
#  {'record_id': '128',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'BREMSBELÄGE'},
#  {'record_id': '128',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'VORNE'},
#  {'record_id': '128',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'BMW'},
#  {'record_id': '128',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': '3'},
#  {'record_id': '128',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Z'},
#  {'record_id': '128',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Z4'},
#  {'record_id': '128',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'BMW'},
#  {'record_id': '130',
#   'category': '2',
#   'aspect_name': 'Produktart',
#   'span': 'Steuerkettensatz'},
#  {'record_id': '130',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'Audi'},
#  {'record_id': '130',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'A8'},
#  {'record_id': '130',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Jahr',
#   'span': '04-10'},
#  {'record_id': '134',
#   'category': '2',
#   'aspect_name': 'Hersteller',
#   'span': 'FAI AutoParts'},
#  {'record_id': '134',
#   'category': '2',
#   'aspect_name': 'Herstellernummer',
#   'span': 'TCK89L'},
#  {'record_id': '134',
#   'category': '2',
#   'aspect_name': 'Produktart',
#   'span': 'Steuerkettensatz'},
#  {'record_id': '134',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'DAIMLER'},
#  {'record_id': '134',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'JAGUAR'},
#  {'record_id': '140',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsscheiben'},
#  {'record_id': '140',
#   'category': '1',
#   'aspect_name': 'Bremsscheiben-Aussendurchmesser',
#   'span': '282,5mm'},
#  {'record_id': '140',
#   'category': '1',
#   'aspect_name': 'Bremsscheibenart',
#   'span': 'belüftet'},
#  {'record_id': '140',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsbeläge'},
#  {'record_id': '140',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'Chrysler'},
#  {'record_id': '140',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Voyager'},
#  {'record_id': '143',
#   'category': '2',
#   'aspect_name': 'Produktart',
#   'span': 'Zahnriemen'},
#  {'record_id': '143',
#   'category': '2',
#   'aspect_name': 'Hersteller',
#   'span': 'CONTI'},
#  {'record_id': '143',
#   'category': '2',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Rollen'},
#  {'record_id': '143',
#   'category': '2',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'WaPu'},
#  {'record_id': '143',
#   'category': '2',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Keilr.'},
#  {'record_id': '143',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'OPEL'},
#  {'record_id': '143',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Astra J'},
#  {'record_id': '143',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Jahr',
#   'span': '2012'},
#  {'record_id': '144',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'Peugeot'},
#  {'record_id': '144',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': '308'},
#  {'record_id': '144',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsscheiben'},
#  {'record_id': '144',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsbeläge'},
#  {'record_id': '144',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'vorne'},
#  {'record_id': '144',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'Vorderachse'},
#  {'record_id': '158',
#   'category': '2',
#   'aspect_name': 'Hersteller',
#   'span': 'FAI AutoParts'},
#  {'record_id': '158',
#   'category': '2',
#   'aspect_name': 'Herstellernummer',
#   'span': '(TCK203VVT)'},
#  {'record_id': '158',
#   'category': '2',
#   'aspect_name': 'Produktart',
#   'span': 'Steuerkettensatz'},
#  {'record_id': '158',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'HYUNDAI'},
#  {'record_id': '158',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'KIA'},
#  {'record_id': '164',
#   'category': '1',
#   'aspect_name': 'Hersteller',
#   'span': 'Febi'},
#  {'record_id': '164',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsscheiben'},
#  {'record_id': '164',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsbeläge'},
#  {'record_id': '164',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'Ford'},
#  {'record_id': '164',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Fiesta VII'},
#  {'record_id': '164',
#   'category': '1',
#   'aspect_name': 'Produktart',
#   'span': 'Satz'},
#  {'record_id': '164',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'hinten'},
#  {'record_id': '177',
#   'category': '2',
#   'aspect_name': 'Hersteller',
#   'span': 'BOSCH'},
#  {'record_id': '177',
#   'category': '2',
#   'aspect_name': 'Produktart',
#   'span': 'Zahnriemen'},
#  {'record_id': '177',
#   'category': '2',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Spannrolle'},
#  {'record_id': '177',
#   'category': '2',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Wapu'},
#  {'record_id': '177',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Primera'},
#  {'record_id': '177',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Scenic II'},
#  {'record_id': '177',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Megane II'},
#  {'record_id': '177',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Laguna II 1.9'},
#  {'record_id': '186',
#   'category': '2',
#   'aspect_name': 'Produktart',
#   'span': 'ZAHNRIEMEN'},
#  {'record_id': '186',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'HONDA'},
#  {'record_id': '186',
#   'category': '2',
#   'aspect_name': 'Hersteller',
#   'span': 'CONTINENTAL'},
#  {'record_id': '190',
#   'category': '2',
#   'aspect_name': 'Hersteller',
#   'span': 'D.I.D.'},
#  {'record_id': '190',
#   'category': '2',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Steuerkettenschloß'},
#  {'record_id': '190',
#   'category': '2',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Steuerketten'},
#  {'record_id': '197',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsscheiben'},
#  {'record_id': '197',
#   'category': '1',
#   'aspect_name': 'Bremsscheiben-Aussendurchmesser',
#   'span': '300'},
#  {'record_id': '197',
#   'category': '1',
#   'aspect_name': 'Bremsscheibenart',
#   'span': 'belüftet'},
#  {'record_id': '197',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsbeläge'},
#  {'record_id': '197',
#   'category': '1',
#   'aspect_name': 'Produktart',
#   'span': 'Bremsensatz'},
#  {'record_id': '197',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'vorne'},
#  {'record_id': '197',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'Ford'},
#  {'record_id': '197',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Mondeo III'},
#  {'record_id': '200',
#   'category': '1',
#   'aspect_name': 'Hersteller',
#   'span': 'Bosch'},
#  {'record_id': '200',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsscheiben'},
#  {'record_id': '200',
#   'category': '1',
#   'aspect_name': 'Bremsscheiben-Aussendurchmesser',
#   'span': '256mm'},
#  {'record_id': '200',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsbeläge'},
#  {'record_id': '200',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'vorne'},
#  {'record_id': '200',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'VW'},
#  {'record_id': '207',
#   'category': '2',
#   'aspect_name': 'Hersteller',
#   'span': 'BOSCH'},
#  {'record_id': '207',
#   'category': '2',
#   'aspect_name': 'Produktart',
#   'span': 'Zahnriemensatz'},
#  {'record_id': '207',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'AUDI'},
#  {'record_id': '207',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'SEAT'},
#  {'record_id': '207',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'SKODA'},
#  {'record_id': '207',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'VW'},
#  {'record_id': '207',
#   'category': '2',
#   'aspect_name': 'Herstellernummer',
#   'span': '1 987 946 564'},
#  {'record_id': '208',
#   'category': '1',
#   'aspect_name': 'Hersteller',
#   'span': 'FEBI'},
#  {'record_id': '208',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'BREMSSCHEIBEN'},
#  {'record_id': '208',
#   'category': '1',
#   'aspect_name': 'Bremsscheiben-Aussendurchmesser',
#   'span': '256MM'},
#  {'record_id': '208',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'BELÄGE'},
#  {'record_id': '208',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'VORNE'},
#  {'record_id': '208',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'AUDI'},
#  {'record_id': '208',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'A3'},
#  {'record_id': '208',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'VW'},
#  {'record_id': '208',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'POLO'},
#  {'record_id': '208',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'SEAT'},
#  {'record_id': '208',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'IBIZA'},
#  {'record_id': '208',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'SKODA'},
#  {'record_id': '214',
#   'category': '1',
#   'aspect_name': 'Hersteller',
#   'span': 'Textar'},
#  {'record_id': '214',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsscheiben'},
#  {'record_id': '214',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsbeläge'},
#  {'record_id': '214',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'vorne'},
#  {'record_id': '214',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'Suzuki'},
#  {'record_id': '214',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Swift III 1,6'},
#  {'record_id': '219',
#   'category': '2',
#   'aspect_name': 'Hersteller',
#   'span': 'Conti CONTITECH'},
#  {'record_id': '219',
#   'category': '2',
#   'aspect_name': 'Hersteller',
#   'span': 'Conti Tech'},
#  {'record_id': '219',
#   'category': '2',
#   'aspect_name': 'Produktart',
#   'span': 'Zahnriemen-Kit'},
#  {'record_id': '219',
#   'category': '2',
#   'aspect_name': 'Herstellernummer',
#   'span': 'CT939K2'},
#  {'record_id': '223',
#   'category': '2',
#   'aspect_name': 'Produktart',
#   'span': 'Set'},
#  {'record_id': '223',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'ALFA'},
#  {'record_id': '224',
#   'category': '1',
#   'aspect_name': 'Produktart',
#   'span': 'BREMSANLAGE'},
#  {'record_id': '224',
#   'category': '1',
#   'aspect_name': 'Bremsscheiben-Aussendurchmesser',
#   'span': '365'},
#  {'record_id': '224', 'category': '1', 'aspect_name': 'Stärke', 'span': '36'},
#  {'record_id': '224',
#   'category': '1',
#   'aspect_name': 'Maßeinheit',
#   'span': 'mm'},
#  {'record_id': '224',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'VOLKSWAGEN'},
#  {'record_id': '224',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'VW'},
#  {'record_id': '224',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'T5'},
#  {'record_id': '224',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'T6'},
#  {'record_id': '224',
#   'category': '1',
#   'aspect_name': 'Hersteller',
#   'span': 'BREMBO'},
#  {'record_id': '224',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'BREMSSATTEL'},
#  {'record_id': '231',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsscheiben'},
#  {'record_id': '231',
#   'category': '1',
#   'aspect_name': 'Bremsscheiben-Aussendurchmesser',
#   'span': '288'},
#  {'record_id': '231',
#   'category': '1',
#   'aspect_name': 'Maßeinheit',
#   'span': 'mm'},
#  {'record_id': '231',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsbeläge'},
#  {'record_id': '231',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'vorne'},
#  {'record_id': '231',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'VW'},
#  {'record_id': '231',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Caddy'},
#  {'record_id': '234',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsscheiben'},
#  {'record_id': '234',
#   'category': '1',
#   'aspect_name': 'Produktart',
#   'span': 'Set'},
#  {'record_id': '234',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'vorne'},
#  {'record_id': '234',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremstrommel'},
#  {'record_id': '234',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'hinten'},
#  {'record_id': '234',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'Opel'},
#  {'record_id': '234',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Vectra A'},
#  {'record_id': '241',
#   'category': '1',
#   'aspect_name': 'Produktart',
#   'span': 'BREMSANLAGE'},
#  {'record_id': '241',
#   'category': '1',
#   'aspect_name': 'Bremsscheiben-Aussendurchmesser',
#   'span': '347'},
#  {'record_id': '241', 'category': '1', 'aspect_name': 'Stärke', 'span': '30'},
#  {'record_id': '241',
#   'category': '1',
#   'aspect_name': 'Maßeinheit',
#   'span': 'mm'},
#  {'record_id': '241',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'AUDI'},
#  {'record_id': '241',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'S2 20V TURBO 3B'},
#  {'record_id': '241',
#   'category': '1',
#   'aspect_name': 'Hersteller',
#   'span': 'BREMBO'},
#  {'record_id': '241',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'BREMSSATTEL'},
#  {'record_id': '254',
#   'category': '1',
#   'aspect_name': 'Hersteller',
#   'span': 'ZIMMERMANN'},
#  {'record_id': '254',
#   'category': '1',
#   'aspect_name': 'Produktlinie',
#   'span': 'SPORT'},
#  {'record_id': '254',
#   'category': '1',
#   'aspect_name': 'Produktart',
#   'span': 'BREMSE'},
#  {'record_id': '254',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'BREMSSCHEIBEN'},
#  {'record_id': '254',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'VOR'},
#  {'record_id': '254',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'BMW'},
#  {'record_id': '254',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'X5 E53 3.0 d'},
#  {'record_id': '255',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'Skoda'},
#  {'record_id': '255',
#   'category': '1',
#   'aspect_name': 'Hersteller',
#   'span': 'Metzger'},
#  {'record_id': '255',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsscheiben'},
#  {'record_id': '255',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsbeläge'},
#  {'record_id': '255',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Warnkabel'},
#  {'record_id': '255',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'vorne'},
#  {'record_id': '257',
#   'category': '2',
#   'aspect_name': 'Hersteller',
#   'span': 'ORIGINAL'},
#  {'record_id': '257',
#   'category': '2',
#   'aspect_name': 'Hersteller',
#   'span': 'CONTI'},
#  {'record_id': '257',
#   'category': '2',
#   'aspect_name': 'Produktart',
#   'span': 'ZAHNRIEMENSATZ'},
#  {'record_id': '257',
#   'category': '2',
#   'aspect_name': 'Herstellernummer',
#   'span': 'CT989K1'},
#  {'record_id': '257',
#   'category': '2',
#   'aspect_name': 'Anzahl_Der_Einheiten',
#   'span': '2'},
#  {'record_id': '257',
#   'category': '2',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'SPANNROLLEN)'},
#  {'record_id': '271',
#   'category': '1',
#   'aspect_name': 'Hersteller',
#   'span': 'Zimmermann'},
#  {'record_id': '271',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsscheiben'},
#  {'record_id': '271',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Beläge'},
#  {'record_id': '271',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'FORD'},
#  {'record_id': '271',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Galaxy'},
#  {'record_id': '271',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'VW'},
#  {'record_id': '271',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Sharan'},
#  {'record_id': '271',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'vorne'},
#  {'record_id': '271',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'hinten'},
#  {'record_id': '275',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'Peugeot'},
#  {'record_id': '275',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Boxer'},
#  {'record_id': '275',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsscheiben'},
#  {'record_id': '275',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsbeläge'},
#  {'record_id': '275',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'vorne'},
#  {'record_id': '275',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'hint'},
#  {'record_id': '276',
#   'category': '2',
#   'aspect_name': 'Hersteller',
#   'span': 'SNR'},
#  {'record_id': '276',
#   'category': '2',
#   'aspect_name': 'Produktart',
#   'span': 'Timing Belt Set'},
#  {'record_id': '276',
#   'category': '2',
#   'aspect_name': 'Herstellernummer',
#   'span': 'KDP457.540'},
#  {'record_id': '277',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsscheiben'},
#  {'record_id': '277',
#   'category': '1',
#   'aspect_name': 'Bremsscheiben-Aussendurchmesser',
#   'span': '257'},
#  {'record_id': '277',
#   'category': '1',
#   'aspect_name': 'Maßeinheit',
#   'span': 'mm'},
#  {'record_id': '277',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsbeläge'},
#  {'record_id': '277',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'vorne'},
#  {'record_id': '277',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'Opel'},
#  {'record_id': '277',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Corsa D'},
#  {'record_id': '282',
#   'category': '2',
#   'aspect_name': 'Hersteller',
#   'span': 'CONTI'},
#  {'record_id': '282',
#   'category': '2',
#   'aspect_name': 'Produktart',
#   'span': 'Zahnriemen'},
#  {'record_id': '282',
#   'category': '2',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Rollen'},
#  {'record_id': '282',
#   'category': '2',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Wasserpumpe'},
#  {'record_id': '282',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'SKODA'},
#  {'record_id': '282',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Octavia'},
#  {'record_id': '282',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Fabia'},
#  {'record_id': '282',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Roomster'},
#  {'record_id': '282',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Superb 1.9TDI'},
#  {'record_id': '283',
#   'category': '1',
#   'aspect_name': 'Hersteller',
#   'span': 'Textar'},
#  {'record_id': '283',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsscheiben'},
#  {'record_id': '283',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsbeläge'},
#  {'record_id': '283',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'Ford'},
#  {'record_id': '283',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Transit'},
#  {'record_id': '283',
#   'category': '1',
#   'aspect_name': 'Produktart',
#   'span': 'Satz'},
#  {'record_id': '283',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'vorne'},
#  {'record_id': '294',
#   'category': '1',
#   'aspect_name': 'Hersteller',
#   'span': 'BREMBO'},
#  {'record_id': '294',
#   'category': '1',
#   'aspect_name': 'Produktart',
#   'span': 'Bremsenset'},
#  {'record_id': '294',
#   'category': '1',
#   'aspect_name': 'Bremsscheibenart',
#   'span': 'gelocht'},
#  {'record_id': '294',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'BMW'},
#  {'record_id': '294',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Z3'},
#  {'record_id': '294',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Z4 (E85)'},
#  {'record_id': '294',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'Vorne'},
#  {'record_id': '294',
#   'category': '1',
#   'aspect_name': 'Bremsscheiben-Aussendurchmesser',
#   'span': '286MM'},
#  {'record_id': '298',
#   'category': '2',
#   'aspect_name': 'Hersteller',
#   'span': 'CONTITECH'},
#  {'record_id': '298',
#   'category': '2',
#   'aspect_name': 'Herstellernummer',
#   'span': 'CT718WP1'},
#  {'record_id': '298',
#   'category': '2',
#   'aspect_name': 'Produktart',
#   'span': 'Zahnriemensatz'},
#  {'record_id': '298',
#   'category': '2',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'WAPU'},
#  {'record_id': '298',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'PEUGEOT'},
#  {'record_id': '298',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'CITROËN'},
#  {'record_id': '317',
#   'category': '2',
#   'aspect_name': 'Produktart',
#   'span': 'Zahnriemen'},
#  {'record_id': '317',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'SEAT'},
#  {'record_id': '317',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'SKODA'},
#  {'record_id': '321',
#   'category': '1',
#   'aspect_name': 'Hersteller',
#   'span': 'ATE'},
#  {'record_id': '321',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'BREMSSCHEIBEN'},
#  {'record_id': '321',
#   'category': '1',
#   'aspect_name': 'Bremsscheiben-Aussendurchmesser',
#   'span': 'Ø294'},
#  {'record_id': '321',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': '+BELÄGE'},
#  {'record_id': '321',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': '+VWK'},
#  {'record_id': '321',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': '+HANDBREMSBACKEN'},
#  {'record_id': '321',
#   'category': '1',
#   'aspect_name': 'Produktart',
#   'span': 'SET'},
#  {'record_id': '321',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'HINTEN'},
#  {'record_id': '321',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'BMW'},
#  {'record_id': '321',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': '3-ER E46'},
#  {'record_id': '325',
#   'category': '1',
#   'aspect_name': 'Hersteller',
#   'span': 'Ate'},
#  {'record_id': '325',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsscheiben'},
#  {'record_id': '325',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsbeläge'},
#  {'record_id': '325',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'Fiat'},
#  {'record_id': '325',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Grande Punto'},
#  {'record_id': '325',
#   'category': '1',
#   'aspect_name': 'Produktart',
#   'span': 'Satz'},
#  {'record_id': '325',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'hinten'},
#  {'record_id': '328',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'OPEL'},
#  {'record_id': '328',
#   'category': '2',
#   'aspect_name': 'Produktart',
#   'span': 'Zahnriemensatz'},
#  {'record_id': '328',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Astra'},
#  {'record_id': '328',
#   'category': '2',
#   'aspect_name': 'Herstellernummer',
#   'span': '95516740'},
#  {'record_id': '331',
#   'category': '2',
#   'aspect_name': 'Produktart',
#   'span': 'ZAHNRIEMENSATZ'},
#  {'record_id': '331',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'CHRYSLER'},
#  {'record_id': '331',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'CRUISE'},
#  {'record_id': '331',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'NEON PL'},
#  {'record_id': '340',
#   'category': '2',
#   'aspect_name': 'Hersteller',
#   'span': 'FEBI BILSTEIN'},
#  {'record_id': '340',
#   'category': '2',
#   'aspect_name': 'Herstellernummer',
#   'span': '47700'},
#  {'record_id': '340',
#   'category': '2',
#   'aspect_name': 'Produktart',
#   'span': 'Timing Chain Kit'},
#  {'record_id': '340',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'PORSCHE'},
#  {'record_id': '343',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'Toyota'},
#  {'record_id': '343',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsscheiben'},
#  {'record_id': '343',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Be'},
#  {'record_id': '343',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'vorne'},
#  {'record_id': '343',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'hint'},
#  {'record_id': '345',
#   'category': '2',
#   'aspect_name': 'Produktart',
#   'span': 'ZAHNRIEMENSATZ'},
#  {'record_id': '345',
#   'category': '2',
#   'aspect_name': 'Produktart',
#   'span': 'ZAHNRIEMEN'},
#  {'record_id': '345',
#   'category': '2',
#   'aspect_name': 'Produktart',
#   'span': 'ZAHNRIEMENSET'},
#  {'record_id': '345',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'KIA'},
#  {'record_id': '345',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Jahr',
#   'span': '04'},
#  {'record_id': '348',
#   'category': '2',
#   'aspect_name': 'Produktart',
#   'span': 'Steuerkettensatz'},
#  {'record_id': '348',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'VW'},
#  {'record_id': '348',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'Audi'},
#  {'record_id': '348',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'Skoda'},
#  {'record_id': '351',
#   'category': '1',
#   'aspect_name': 'Hersteller',
#   'span': 'ZIMMERMANN'},
#  {'record_id': '351',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Scheibenbremse'},
#  {'record_id': '351',
#   'category': '1',
#   'aspect_name': 'Produktart',
#   'span': 'Bremsensatz'},
#  {'record_id': '351',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'Hinten'},
#  {'record_id': '351',
#   'category': '1',
#   'aspect_name': 'Herstellernummer',
#   'span': '640.4245.00'},
#  {'record_id': '351',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'Opel'},
#  {'record_id': '351',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Astra'},
#  {'record_id': '352',
#   'category': '2',
#   'aspect_name': 'Hersteller',
#   'span': 'HEPU'},
#  {'record_id': '352',
#   'category': '2',
#   'aspect_name': 'Herstellernummer',
#   'span': '21-0509'},
#  {'record_id': '352',
#   'category': '2',
#   'aspect_name': 'Produktart',
#   'span': 'Steuerkettensatz'},
#  {'record_id': '352',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'RENAULT'},
#  {'record_id': '356',
#   'category': '1',
#   'aspect_name': 'Hersteller',
#   'span': 'EBC'},
#  {'record_id': '356',
#   'category': '1',
#   'aspect_name': 'Produktart',
#   'span': 'Bremsen Kit'},
#  {'record_id': '356',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'Vorne'},
#  {'record_id': '356',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Beläge'},
#  {'record_id': '356',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Scheiben'},
#  {'record_id': '356',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'BMW'},
#  {'record_id': '360',
#   'category': '1',
#   'aspect_name': 'Hersteller',
#   'span': 'ATE'},
#  {'record_id': '360',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsscheiben'},
#  {'record_id': '360',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsbeläg'},
#  {'record_id': '360',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'vor'},
#  {'record_id': '360',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'hint'},
#  {'record_id': '360',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'BMW'},
#  {'record_id': '360',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'MINI'},
#  {'record_id': '368',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsscheiben'},
#  {'record_id': '368',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsbeläge'},
#  {'record_id': '368',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'VW'},
#  {'record_id': '368',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Transporter T5'},
#  {'record_id': '368',
#   'category': '1',
#   'aspect_name': 'Produktart',
#   'span': 'Satz'},
#  {'record_id': '368',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'vorne'},
#  {'record_id': '372',
#   'category': '2',
#   'aspect_name': 'Produktart',
#   'span': 'Zahnriemen'},
#  {'record_id': '372',
#   'category': '2',
#   'aspect_name': 'Hersteller',
#   'span': 'CONTI'},
#  {'record_id': '372',
#   'category': '2',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Rollen'},
#  {'record_id': '372',
#   'category': '2',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'WaPu'},
#  {'record_id': '372',
#   'category': '2',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Keilr.'},
#  {'record_id': '372',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'OPEL'},
#  {'record_id': '375',
#   'category': '1',
#   'aspect_name': 'Anzahl_Der_Einheiten',
#   'span': '2x'},
#  {'record_id': '375',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremssattel'},
#  {'record_id': '375',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsscheiben'},
#  {'record_id': '375',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsbeläge'},
#  {'record_id': '375',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'vorne'},
#  {'record_id': '375',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'BMW'},
#  {'record_id': '375',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Z'},
#  {'record_id': '377',
#   'category': '1',
#   'aspect_name': 'Hersteller',
#   'span': 'ATE'},
#  {'record_id': '377',
#   'category': '1',
#   'aspect_name': 'Produktart',
#   'span': 'BREMSENSET'},
#  {'record_id': '377',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'VORNE'},
#  {'record_id': '377',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'BREMSSCHEIBEN'},
#  {'record_id': '377',
#   'category': '1',
#   'aspect_name': 'Bremsscheiben-Aussendurchmesser',
#   'span': '324mm'},
#  {'record_id': '377',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'BELÄGE'},
#  {'record_id': '377',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'VOLVO'},
#  {'record_id': '380',
#   'category': '2',
#   'aspect_name': 'Hersteller',
#   'span': 'INA'},
#  {'record_id': '380',
#   'category': '2',
#   'aspect_name': 'Herstellernummer',
#   'span': '530060210'},
#  {'record_id': '380',
#   'category': '2',
#   'aspect_name': 'Produktart',
#   'span': 'Zahnriemensatz'},
#  {'record_id': '380',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'CITROËN'},
#  {'record_id': '380',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'FIAT'},
#  {'record_id': '391',
#   'category': '2',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'STEUERKETTE'},
#  {'record_id': '391',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'MERCEDES BENZ'},
#  {'record_id': '391',
#   'category': '2',
#   'aspect_name': 'Hersteller',
#   'span': 'FEBI BILSTEIN'},
# ...
#   'category': '1',
#   'aspect_name': 'Hersteller',
#   'span': 'ATE'},
#  {'record_id': '631',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsscheiben'},
#  {'record_id': '631',
#   'category': '1',
#   'aspect_name': 'Bremsscheiben-Aussendurchmesser',
#   'span': '240Mm'},
#  {'record_id': '631',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': '+Beläge'},
#  {'record_id': '631',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'vorne'},
#  {'record_id': '631',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'Ford'},
#  {'record_id': '631',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Ka'},
#  {'record_id': '631',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Courier'},
#  {'record_id': '634',
#   'category': '1',
#   'aspect_name': 'Hersteller',
#   'span': 'FEBI'},
#  {'record_id': '634',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsscheiben'},
#  {'record_id': '634',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsbeläge'},
#  {'record_id': '634',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Wkt.'},
#  {'record_id': '634',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'Mini'},
#  {'record_id': '634',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'R50/52/R53'},
#  {'record_id': '634',
#   'category': '1',
#   'aspect_name': 'Produktart',
#   'span': 'Satz'},
#  {'record_id': '634',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'Vorne'},
#  {'record_id': '635',
#   'category': '1',
#   'aspect_name': 'Hersteller',
#   'span': 'EBC'},
#  {'record_id': '635',
#   'category': '1',
#   'aspect_name': 'Produktart',
#   'span': 'Bremsen Kit'},
#  {'record_id': '635',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'Vorne'},
#  {'record_id': '635',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Beläge'},
#  {'record_id': '635',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Scheiben'},
#  {'record_id': '635',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'Audi'},
#  {'record_id': '635',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'A6'},
#  {'record_id': '635',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'A7'},
#  {'record_id': '635',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Q5'},
#  {'record_id': '636',
#   'category': '2',
#   'aspect_name': 'Produktart',
#   'span': 'ZAHNRIEMEN'},
#  {'record_id': '636',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'CITROËN'},
#  {'record_id': '636',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'PEUGEOT'},
#  {'record_id': '636',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'C3'},
#  {'record_id': '636',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'PICASSO'},
#  {'record_id': '640',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsscheiben'},
#  {'record_id': '640',
#   'category': '1',
#   'aspect_name': 'Bremsscheiben-Aussendurchmesser',
#   'span': '288'},
#  {'record_id': '640',
#   'category': '1',
#   'aspect_name': 'Maßeinheit',
#   'span': 'mm'},
#  {'record_id': '640',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsbeläge'},
#  {'record_id': '640',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'vorne'},
#  {'record_id': '640',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'Mercedes'},
#  {'record_id': '647',
#   'category': '1',
#   'aspect_name': 'Hersteller',
#   'span': 'ATE'},
#  {'record_id': '647',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'BREMSSCHEIBEN'},
#  {'record_id': '647',
#   'category': '1',
#   'aspect_name': 'Bremsscheiben-Aussendurchmesser',
#   'span': '300mm'},
#  {'record_id': '647',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'BELÄGE'},
#  {'record_id': '647',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'VORNE'},
#  {'record_id': '647',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'OPEL'},
#  {'record_id': '647',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'ASTRA J'},
#  {'record_id': '647',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'ZAFIRA C TOURER'},
#  {'record_id': '654',
#   'category': '1',
#   'aspect_name': 'Produktart',
#   'span': 'Bremsen Set'},
#  {'record_id': '654',
#   'category': '1',
#   'aspect_name': 'Bremsscheiben-Aussendurchmesser',
#   'span': '276'},
#  {'record_id': '654',
#   'category': '1',
#   'aspect_name': 'Maßeinheit',
#   'span': 'mm'},
#  {'record_id': '654',
#   'category': '1',
#   'aspect_name': 'Bremsscheiben-Aussendurchmesser',
#   'span': '259'},
#  {'record_id': '654',
#   'category': '1',
#   'aspect_name': 'Maßeinheit',
#   'span': 'mm'},
#  {'record_id': '654',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'vorne'},
#  {'record_id': '654',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'hinten'},
#  {'record_id': '654',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'Mini Cooper'},
#  {'record_id': '655',
#   'category': '1',
#   'aspect_name': 'Hersteller',
#   'span': 'ATE'},
#  {'record_id': '655',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsscheiben'},
#  {'record_id': '655',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Beläge'},
#  {'record_id': '655',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'Vorderachse(VA)'},
#  {'record_id': '655',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'RENAULT'},
#  {'record_id': '655',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'SCÉNIC II (JM0/1_)'},
#  {'record_id': '656',
#   'category': '2',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'WASSERPUMPE'},
#  {'record_id': '656',
#   'category': '2',
#   'aspect_name': 'Produktart',
#   'span': 'ZAHNRIEMENSATZ'},
#  {'record_id': '656',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'VW'},
#  {'record_id': '656',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'UP!'},
#  {'record_id': '656',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'POLO/Van/CityVan/VI LOAD'},
#  {'record_id': '656',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'SEAT'},
#  {'record_id': '656',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Mii 1.0L'},
#  {'record_id': '663',
#   'category': '1',
#   'aspect_name': 'Modell',
#   'span': 'Turbo Groove'},
#  {'record_id': '663',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsscheiben,'},
#  {'record_id': '663',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Beläge'},
#  {'record_id': '663',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'vorne'},
#  {'record_id': '663',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'Audi'},
#  {'record_id': '663',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'A5 Sportback 8TA'},
#  {'record_id': '663',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Jahr',
#   'span': '09-17'},
#  {'record_id': '668',
#   'category': '2',
#   'aspect_name': 'Hersteller',
#   'span': 'FEBI BILSTEIN'},
#  {'record_id': '668',
#   'category': '2',
#   'aspect_name': 'Produktart',
#   'span': 'Steuerkettensatz'},
#  {'record_id': '668',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'VW'},
#  {'record_id': '668',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Touran'},
#  {'record_id': '668',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'AUDI'},
#  {'record_id': '668',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'A3'},
#  {'record_id': '668',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Golf V'},
#  {'record_id': '668',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'SKODA'},
#  {'record_id': '669',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'Toyota'},
#  {'record_id': '669',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'RAV 4 III'},
#  {'record_id': '669',
#   'category': '1',
#   'aspect_name': 'Produktart',
#   'span': 'Bremsen Set'},
#  {'record_id': '669',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'VOR'},
#  {'record_id': '675',
#   'category': '1',
#   'aspect_name': 'Hersteller',
#   'span': 'TRW'},
#  {'record_id': '675',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsscheiben'},
#  {'record_id': '675',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsbeläge'},
#  {'record_id': '675',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Wkt.'},
#  {'record_id': '675',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'Mercedes'},
#  {'record_id': '675',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'A'},
#  {'record_id': '675',
#   'category': '1',
#   'aspect_name': 'Produktart',
#   'span': 'Satz'},
#  {'record_id': '675',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'vorne'},
#  {'record_id': '676',
#   'category': '1',
#   'aspect_name': 'Hersteller',
#   'span': 'BREMBO'},
#  {'record_id': '676',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'BREMSSCHEIBEN'},
#  {'record_id': '676',
#   'category': '1',
#   'aspect_name': 'Bremsscheiben-Aussendurchmesser',
#   'span': 'Ø266MM'},
#  {'record_id': '676',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'BREMSBELÄGE'},
#  {'record_id': '676',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'VORNE'},
#  {'record_id': '676',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'CITROEN'},
#  {'record_id': '678',
#   'category': '2',
#   'aspect_name': 'Produktart',
#   'span': 'ZAHNRIEMENSATZ'},
#  {'record_id': '678',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'FIAT'},
#  {'record_id': '678',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'ALFA ROMEO'},
#  {'record_id': '678',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'LANCIA'},
#  {'record_id': '689',
#   'category': '2',
#   'aspect_name': 'Hersteller',
#   'span': 'FAI'},
#  {'record_id': '689',
#   'category': '2',
#   'aspect_name': 'Produktart',
#   'span': 'Steuerkettensatz'},
#  {'record_id': '689',
#   'category': '2',
#   'aspect_name': 'Herstellernummer',
#   'span': 'TCK35VVT'},
#  {'record_id': '689',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'TOYOTA'},
#  {'record_id': '689',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'DOHC'},
#  {'record_id': '689',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'AVENSIS'},
#  {'record_id': '689',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Jahr',
#   'span': '00-03'},
#  {'record_id': '689',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Jahr',
#   'span': '99-'},
#  {'record_id': '695',
#   'category': '2',
#   'aspect_name': 'Hersteller',
#   'span': 'INA'},
#  {'record_id': '695',
#   'category': '2',
#   'aspect_name': 'Herstellernummer',
#   'span': '559 0106 10'},
#  {'record_id': '695',
#   'category': '2',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Steuerkette'},
#  {'record_id': '695',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'FORD'},
#  {'record_id': '695',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Focus C-Max (DM2)'},
#  {'record_id': '700',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'Renault'},
#  {'record_id': '700',
#   'category': '2',
#   'aspect_name': 'Produktart',
#   'span': 'Zahnriemen'},
#  {'record_id': '700',
#   'category': '2',
#   'aspect_name': 'Produktart',
#   'span': 'Zahnriemensatz'},
#  {'record_id': '700',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Laguna'},
#  {'record_id': '700',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Clio'},
#  {'record_id': '700',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Megane'},
#  {'record_id': '700',
#   'category': '2',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Scenic'},
#  {'record_id': '700',
#   'category': '2',
#   'aspect_name': 'Herstellernummer',
#   'span': '130'},
#  {'record_id': '703',
#   'category': '1',
#   'aspect_name': 'Hersteller',
#   'span': 'ATE'},
#  {'record_id': '703',
#   'category': '1',
#   'aspect_name': 'Modell',
#   'span': 'Powerdisc'},
#  {'record_id': '703',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsscheiben'},
#  {'record_id': '703',
#   'category': '1',
#   'aspect_name': 'Bremsscheiben-Aussendurchmesser',
#   'span': 'Ø288mm'},
#  {'record_id': '703',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'vorne'},
#  {'record_id': '703',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'AUDI'},
#  {'record_id': '703',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'A3 8P'},
#  {'record_id': '703',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'SEAT'},
#  {'record_id': '703',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Leon'},
#  {'record_id': '703',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Altea'},
#  {'record_id': '706',
#   'category': '2',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'WASSERPUMPE'},
#  {'record_id': '706',
#   'category': '2',
#   'aspect_name': 'Produktart',
#   'span': 'ZAHNRIEMENSATZ'},
#  {'record_id': '706',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'MITSUBISHI'},
#  {'record_id': '706',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'SKODA'},
#  {'record_id': '707',
#   'category': '1',
#   'aspect_name': 'Hersteller',
#   'span': 'ATE'},
#  {'record_id': '707',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsscheiben'},
#  {'record_id': '707',
#   'category': '1',
#   'aspect_name': 'Bremsscheiben-Aussendurchmesser',
#   'span': 'Ø282'},
#  {'record_id': '707',
#   'category': '1',
#   'aspect_name': 'Bremsscheibenart',
#   'span': 'massiv'},
#  {'record_id': '707',
#   'category': '1',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Bremsbeläge'},
#  {'record_id': '707',
#   'category': '1',
#   'aspect_name': 'Einbauposition',
#   'span': 'vorne'},
#  {'record_id': '707',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'VW'},
#  {'record_id': '710',
#   'category': '2',
#   'aspect_name': 'Hersteller',
#   'span': 'CONTINENTAL CTAM'},
#  {'record_id': '710',
#   'category': '2',
#   'aspect_name': 'Herstellernummer',
#   'span': 'CT1099WP2'},
#  {'record_id': '710',
#   'category': '2',
#   'aspect_name': 'Im_Lieferumfang_Enthalten',
#   'span': 'Wasserpumpe'},
#  {'record_id': '710',
#   'category': '2',
#   'aspect_name': 'Produktart',
#   'span': 'Zahnriemensatz'},
#  {'record_id': '710',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'HYUNDAI'},
#  {'record_id': '710',
#   'category': '2',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'KIA'},
#  {'record_id': '711',
#   'category': '1',
#   'aspect_name': 'Kompatible_Fahrzeug_Marke',
#   'span': 'VW'},
#  {'record_id': '711',
#   'category': '1',
#   'aspect_name': 'Kompatibles_Fahrzeug_Modell',
#   'span': 'Polo 6N'},
#  ...]

# %%
def calculate_fbeta(pred, target, beta=0.2):
    # pred, target are sets of tuples like {(r_id, span), ...}
    tp = pred & target  # true positives
    fp = pred - target  # false positives
    fn = target - tp    # false negatives

    beta2 = beta ** 2
    precision = len(tp) / (len(tp) + len(fp)) if (len(tp) + len(fp)) > 0 else 0.0
    recall = len(tp) / (len(tp) + len(fn)) if (len(tp) + len(fn)) > 0 else 0.0

    if precision == 0 and recall == 0:
        fbeta = 0.0
    else:
        fbeta = (1 + beta2) * precision * recall / (beta2 * precision + recall)

    return fbeta

# %%
def compute_fbeta_scores(all_targets, all_preds, beta=0.2):
    """
    Compute per-category and overall weighted F-beta scores.

    Args:
        all_targets (list[dict]): Ground truth records with columns like ['category', 'aspect_name', ...].
        all_preds (list[dict]): Prediction records with same structure as targets.
        beta (float): Beta value for F-beta computation. Default is 0.2 (precision-focused).

    Returns:
        dict: {
            'per_category': {'1': float, '2': float},
            'overall_score': float
        }
    """
    import pandas as pd

    # Convert to DataFrames
    df_target = pd.DataFrame(all_targets)
    df_pred = pd.DataFrame(all_preds)

    results = {'per_category': {}}
    category_scores = []

    # Iterate over both categories
    for cat in ['1', '2']:
        df_target_cat = df_target[df_target['category'] == cat]
        df_pred_cat = df_pred[df_pred['category'] == cat]

        cat_score = 0.0
        total = len(df_target_cat)

        # Iterate over all aspect names within this category
        for aspect_name in df_target_cat['aspect_name'].unique():
            target_rows = df_target_cat[df_target_cat['aspect_name'] == aspect_name]
            pred_rows = df_pred_cat[df_pred_cat['aspect_name'] == aspect_name]

            # Convert rows into sets of tuples (excluding metadata columns)
            target = set(target_rows.drop(columns=['category', 'aspect_name']).apply(tuple, axis=1))
            pred = set(pred_rows.drop(columns=['category', 'aspect_name']).apply(tuple, axis=1))

            # Weighted F-beta for this aspect
            weight = len(target_rows) / total
            cat_score += weight * calculate_fbeta(pred, target, beta=beta)

        results['per_category'][cat] = cat_score
        category_scores.append(cat_score)

    # Compute overall mean across categories
    overall = sum(category_scores) / len(category_scores)
    results['overall_score'] = overall

    return results

# %%
compute_fbeta_scores(all_targets, all_preds)
# Out:
# {'per_category': {'1': 0.892044481550705, '2': 0.9018074896156842},
#  'overall_score': 0.8969259855831946}

# %%
df_target = pd.DataFrame(all_targets)
df_pred = pd.DataFrame(all_preds)

final_score = 0
for cat in ['1','2']:
    df_target_cat = df_target.groupby('category').get_group(cat)
    df_pred_cat = df_pred.groupby('category').get_group(cat)
    cat_score = 0
    total = len(df_target_cat)
    for aspect_name in df_target_cat.aspect_name.unique():
        target = df_target_cat.groupby('aspect_name').get_group(aspect_name)
        pred = df_pred_cat.groupby('aspect_name').get_group(aspect_name)
        target = set(target.drop(columns=['category', 'aspect_name']).apply(tuple, axis=1))
        pred = set(pred.drop(columns=['category', 'aspect_name']).apply(tuple, axis=1))
        # break
        cat_score += (len(target)/total) * calculate_fbeta(pred, target)
        
    final_score += cat_score
final_score /= 2
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 12
#      10 for aspect_name in df_target_cat.aspect_name.unique():
#      11     target = df_target_cat.groupby('aspect_name').get_group(aspect_name)
# ---> 12     pred = df_pred_cat.groupby('aspect_name').get_group(aspect_name)
#      13     target = set(target.drop(columns=['category', 'aspect_name']).apply(tuple, axis=1))
#      14     pred = set(pred.drop(columns=['category', 'aspect_name']).apply(tuple, axis=1))
#
# File ~/anaconda3/envs/ner_env/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:1114, in BaseGroupBy.get_group(self, name, obj)
#    1112 inds = self._get_index(name)
#    1113 if not len(inds):
# -> 1114     raise KeyError(name)
#    1116 if obj is None:
#    1117     indexer = inds if self.axis == 0 else (slice(None), inds)
#
# KeyError: 'Oe/Oem_Referenznummer(N)'

# %%
# Convert prediction and target lists into DataFrames
df_target = pd.DataFrame(all_targets)
df_pred = pd.DataFrame(all_preds)

final_score = 0.0  # overall mean F-beta score across all categories

# Iterate over each category (assumed categorical strings '1' and '2')
for cat in ['1', '2']:
    # Filter data for the current category
    df_target_cat = df_target[df_target['category'] == cat]
    df_pred_cat = df_pred[df_pred['category'] == cat]
    
    cat_score = 0.0  # cumulative weighted F-beta score for this category
    total = len(df_target_cat)  # number of samples in this category

    # Loop through each unique aspect name within the category
    for aspect_name in df_target_cat['aspect_name'].unique():
        # Extract target and prediction rows for this aspect
        target_rows = df_target_cat[df_target_cat['aspect_name'] == aspect_name]
        pred_rows = df_pred_cat[df_pred_cat['aspect_name'] == aspect_name]

        # Convert rows (excluding metadata) into sets of tuples
        # Each tuple uniquely identifies an entity span
        target = set(target_rows.drop(columns=['category', 'aspect_name']).apply(tuple, axis=1))
        pred = set(pred_rows.drop(columns=['category', 'aspect_name']).apply(tuple, axis=1))

        # Compute weighted F-beta score for this aspect
        # Weight by the relative number of target samples in this aspect
        aspect_weight = len(target_rows) / total
        cat_score += aspect_weight * calculate_fbeta(pred, target)

    # Add this category's contribution to the overall score
    final_score += cat_score

# Average the scores across categories
final_score /= 2

# %%
comp
# Out:
# {'per_category': {'1': 0.888177044279952, '2': 0.9007080715287676},
#  'overall_score': 0.8944425579043598,
#  'global_counts': {'tp': 6050, 'fp': 585, 'fn': 1489}}

# %%
final_score
{'per_category': {'1': 0.892044481550705, '2': 0.9018074896156842},
 'overall_score': 0.8969259855831946}
# Out:
# 0.8969259855831946

# %%
len(pred & target)
# Out:
# 407

# %%
set(target.drop(columns=['category', 'aspect_name']).apply(tuple, axis=1))
# Out:
# {('1006', 'BOSCH'),
#  ('1048', 'CONTI'),
#  ('1049', 'FEBI BILSTEIN'),
#  ('1053', 'INA'),
#  ('1056', 'SKF'),
#  ('1075', 'GATES'),
#  ('1079', 'AIC'),
#  ('1088', 'CONTITECH'),
#  ('1098', 'FEBI BILSTEIN'),
#  ('1099', 'GATES'),
#  ('1100', 'CONTI'),
#  ('1112', 'GATES'),
#  ('1119', 'CONTINENTAL CTAM'),
#  ('1142', 'FEBI'),
#  ('1147', 'INA'),
#  ('1148', 'SNR'),
#  ('1149', 'GATES'),
#  ('1161', 'FAI AutoParts'),
#  ('1193', 'INA'),
#  ('1211', 'INA'),
#  ('1234', 'BOSCH'),
#  ('1245', 'CONTI'),
#  ('1261', 'Gates'),
#  ('1263', 'CONTITECH'),
#  ('1291', 'BOSCH'),
#  ('1308', 'INA'),
#  ('1327', 'VAICO'),
#  ('1331', 'CONTINENTAL CTAM'),
#  ('1333', 'SWAG'),
#  ('134', 'FAI AutoParts'),
#  ('1341', 'INA'),
#  ('1355', 'SKF'),
#  ('1357', 'FEBI BILSTEIN'),
#  ('1359', 'CONTINENTAL CTAM'),
#  ('1372', 'FEBI'),
#  ('1390', 'CONTI'),
#  ('1416', 'CONTINENTAL'),
#  ('1418', 'CONTITECH'),
#  ('1422', 'CONTI'),
#  ('1422', 'CONTITECH'),
#  ('143', 'CONTI'),
#  ('1449', 'CONTI'),
#  ('1454', 'CONTI'),
#  ('1466', 'INA'),
#  ('1496', 'DAYCO'),
#  ('1516', 'QH'),
#  ('1540', 'SKF'),
#  ('1559', 'CONTI'),
#  ('1562', 'CONTINENTAL'),
#  ('158', 'FAI AutoParts'),
#  ('1594', 'CONTINENTAL CTAM'),
#  ('1699', 'SNR'),
#  ('17', 'CONTINENTAL CTAM'),
#  ('1704', 'CONTINENTAL'),
#  ('1718', 'AE'),
#  ('1736', 'CONTI'),
#  ('1736', 'MEYLE'),
#  ('1746', 'DAYCO'),
#  ('1746', 'Elring'),
#  ('1748', 'GATES'),
#  ('1751', 'INA'),
#  ('1753', 'CONTINENTAL CTAM'),
#  ('1758', 'FEBI BILSTEIN'),
#  ('177', 'BOSCH'),
#  ('1793', 'FAI AutoParts'),
#  ('1813', 'SKF'),
#  ('1819', 'FEBI'),
#  ('1819', 'Riemenspanner'),
#  ('1832', 'SKF'),
#  ('1848', 'JAPANPARTS'),
#  ('186', 'CONTINENTAL'),
#  ('1880', 'CONTINENTAL CTAM'),
#  ('190', 'D.I.D.'),
#  ('1905', 'MAGNETI MARELLI'),
#  ('1910', '(meyle)'),
#  ('1930', 'EUROREPAR'),
#  ('1967', 'SKF'),
#  ('1975', 'FAI AutoParts'),
#  ('1992', 'BOSCH'),
#  ('1995', 'FAI AutoParts'),
#  ('2002', 'SKF'),
#  ('2009', 'GATES'),
#  ('2020', 'ASHIKA'),
#  ('2025', 'SKF'),
#  ('2027', 'INA'),
#  ('2029', 'DAYCO'),
#  ('2061', 'GATES'),
#  ('2062', 'CONTINENTAL CTAM'),
#  ('207', 'BOSCH'),
#  ('2072', 'DOLZ'),
#  ('2079', 'SKF'),
#  ('2088', 'SKF'),
#  ('2112', 'CONTI'),
#  ('2137', 'SWAG'),
#  ('2145', 'FEBI BILSTEIN'),
#  ('2149', 'FEBI'),
#  ('2161', 'CONTI'),
#  ('219', 'CONTITECH'),
#  ('219', 'Conti'),
#  ('2203', 'BOSCH'),
#  ('2215', 'SKF'),
#  ('2223', 'INA'),
#  ('2226', 'TOPRAN'),
#  ('2253', 'CONTINENTAL CTAM'),
#  ('2255', 'SKF'),
#  ('2260', 'FEBI'),
#  ('2315', 'FEBI BILSTEIN'),
#  ('2331', 'DAYCO'),
#  ('2348', 'CONTI'),
#  ('2371', 'FEBI'),
#  ('2390', 'FEBI BILSTEIN'),
#  ('2408', 'INA'),
#  ('2420', 'SKF'),
#  ('2436', 'Arlows Alu'),
#  ('2442', 'BOSCH'),
#  ('2459', 'SKF'),
#  ('2464', 'FAI'),
#  ('2468', 'FEBI'),
#  ('2473', 'SWAG'),
#  ('2501', 'INA'),
#  ('2503', '"GATES'),
#  ('2511', 'CONTI'),
#  ('2511', 'DexCool'),
#  ('2519', 'GATES'),
#  ('2522', 'FEBI BILSTEIN'),
#  ('2534', 'CONTI'),
#  ('2538', 'BOSCH'),
#  ('2555', 'TOPRAN'),
#  ('2558', 'CONTI'),
#  ('2562', 'BOSCH'),
#  ('257', 'CONTI'),
#  ('2587', 'SKF'),
#  ('2593', 'DAYCO'),
#  ('2612', 'SWAG'),
#  ('2636', 'INA'),
#  ('2638', 'SKF'),
#  ('2646', 'FEBI'),
#  ('2652', 'CONTI'),
#  ('2654', 'BUGIAD'),
#  ('2663', 'INA'),
#  ('2677', 'INA'),
#  ('2712', 'CONTINENTAL CTAM'),
#  ('2717', 'GATES'),
#  ('2720', 'CONTINENTAL'),
#  ('2724', 'FEBI BILSTEIN'),
#  ('2736', 'CONTI'),
#  ('2745', 'INA'),
#  ('2749', 'FEBI BILSTEIN'),
#  ('2751', 'Conti CONTITECH Conti Tech'),
#  ('276', 'SNR'),
#  ('2772', 'INA'),
#  ('2772', 'MAHLE'),
#  ('2790', 'INA'),
#  ('2794', 'BOSCH'),
#  ('2805', 'SNR'),
#  ('2816', 'SKF'),
#  ('282', 'CONTI'),
#  ('2821', 'INA'),
#  ('2865', 'SWAG'),
#  ('2874', 'BOLK'),
#  ('2883', 'SKF'),
#  ('2892', 'CONTI'),
#  ('29', 'CONTITECH'),
#  ('2902', 'HEPU'),
#  ('2919', 'FEBI BILSTEIN Spanner,'),
#  ('2935', 'SKF'),
#  ('2946', 'FAI'),
#  ('2954', 'FAI AutoParts'),
#  ('2967', 'CONTI'),
#  ('2968', 'SKF'),
#  ('2969', 'TOPRAN'),
#  ('2977', 'SWAG'),
#  ('298', 'CONTITECH'),
#  ('2984', 'CONTITECH'),
#  ('2986', 'BOSCH'),
#  ('2996', 'FEBI'),
#  ('3007', 'FEBI'),
#  ('3010', 'CONTI'),
#  ('3012', 'SKF'),
#  ('3052', 'CONTI'),
#  ('3055', 'INA'),
#  ('3057', 'CONTI'),
#  ('3069', 'BOSCH'),
#  ('3069', 'FEBI'),
#  ('3075', 'CONTITECH'),
#  ('3088', 'CONTI'),
#  ('3108', 'BOSCH'),
#  ('3109', 'DAYCO'),
#  ('3114', 'CONTI'),
#  ('3133', 'SKF'),
#  ('3148', 'INA'),
#  ('3148', 'Schaeffler'),
#  ('3152', 'CONTI'),
#  ('3152', 'SRC'),
#  ('3160', 'FAI AutoParts'),
#  ('3165', 'SKF'),
#  ('3191', 'Changchai'),
#  ('3195', 'INA'),
#  ('3209', 'Febi'),
#  ('3213', 'BLUE PRINT'),
#  ('3232', 'FAI AutoParts'),
#  ('3235', 'CONTI'),
#  ('3242', 'DAYCO'),
#  ('3280', 'INA'),
#  ('3287', 'GATES'),
#  ('3297', 'CONTI'),
#  ('3299', 'CONTITECH'),
#  ('3312', 'BOSCH'),
#  ('3322', 'SKF'),
#  ('3324', 'HEPU'),
#  ('3341', 'GATES'),
#  ('3344', 'FAI AutoParts'),
#  ('3373', 'INA'),
#  ('34', 'BOSCH'),
#  ('340', 'FEBI BILSTEIN'),
#  ('3403', 'Omc'),
#  ('3403', 'Vema'),
#  ('3407', 'FEBI BILSTEIN'),
#  ('3454', 'GATES'),
#  ('3480', 'CONTITECH'),
#  ('3483', 'BOSCH'),
#  ('3484', 'GATES'),
#  ('3498', 'SKF'),
#  ('352', 'HEPU'),
#  ('3529', 'INA'),
#  ('3545', 'BOSCH'),
#  ('3553', 'FEBI BILSTEIN'),
#  ('3572', 'FAI AutoParts'),
#  ('3592', 'CONTI'),
#  ('3592', 'MANN'),
#  ('3617', 'SKF'),
#  ('3633', 'INA'),
#  ('3639', 'SKF'),
#  ('3671', 'SKF'),
#  ('3680', 'Conti'),
#  ('3682', 'HEPU'),
#  ('3689', 'Continental Ctam'),
#  ('3693', 'SKF'),
#  ('372', 'CONTI'),
#  ('3739', 'BOSCH'),
#  ('3754', 'INA'),
#  ('3765', 'CONTI'),
#  ('380', 'INA'),
#  ('3832', 'ASHIKA'),
#  ('3834', 'SKF'),
#  ('3839', 'BGA'),
#  ('3848', 'FEBI BILSTEIN'),
#  ('3849', 'SNR'),
#  ('3859', 'INA'),
#  ('3861', 'CONTINENTAL CTAM'),
#  ('3863', 'FEBI BILSTEIN'),
#  ('3866', 'CONTINENTAL CTAM'),
#  ('3878', 'CONTINENTAL'),
#  ('3880', 'BOSCH'),
#  ('3883', 'CONTI'),
#  ('3883', 'FEBI'),
#  ('3883', 'MEYLE'),
#  ('3896', 'BOSCH'),
#  ('3898', 'REINZ'),
#  ('3905', 'BOSCH'),
#  ('3906', 'GATES'),
#  ('391', 'FEBI BILSTEIN'),
#  ('3916', '(SVW)'),
#  ('3916', 'INA'),
#  ('3917', 'INA'),
#  ('3918', 'CONTITECH'),
#  ('392', 'SKF'),
#  ('393', 'INA'),
#  ('394', 'SKF'),
#  ('395', 'FEBI BILSTEIN'),
#  ('3960', 'GATES'),
#  ('3987', 'CONTI'),
#  ('399', 'CONTI'),
#  ('3998', 'CONTITECH'),
#  ('400', 'SKF'),
#  ('4005', 'HEPU'),
#  ('4028', 'INA'),
#  ('4059', 'CONTINENTAL CTAM'),
#  ('4076', 'INA'),
#  ('4108', 'CONTI'),
#  ('4120', 'DOLZ'),
#  ('4128', 'FEBI'),
#  ('4139', 'CONTI'),
#  ('416', 'SKF'),
#  ('4171', 'SKF'),
#  ('4174', 'SWAG'),
#  ('4208', 'SKF'),
#  ('4210', 'CONTI'),
#  ('4223', 'CONTI'),
#  ('4231', 'CONTINENTAL CTAM'),
#  ('4247', 'CONTI'),
#  ('4253', 'DAYCO'),
#  ('4257', 'INA'),
#  ('426', 'FEBI BILSTEIN'),
#  ('428', 'INA'),
#  ('429', 'INA'),
#  ('4291', 'DAYCO'),
#  ('4295', 'FEBI BILSTEIN'),
#  ('4300', 'FAI AutoParts'),
#  ('4320', 'SKF'),
#  ('4325', 'CONTINENTAL CTAM'),
#  ('4332', 'SKF'),
#  ('4334', 'CONTI'),
#  ('4352', 'FEBI BILSTEIN'),
#  ('4374', 'INA'),
#  ('4387', 'CONTITECH'),
#  ('4406', 'INA'),
#  ('4408', 'CONTINENTAL CTAM'),
#  ('4426', 'Hajus'),
#  ('4438', 'HEPU'),
#  ('4499', 'CONTINENTAL'),
#  ('4557', 'FEBI BILSTEIN'),
#  ('4559', 'FAI AutoParts'),
#  ('4564', 'INA'),
#  ('4564', 'MEYLE'),
#  ('4566', 'BOSCH'),
#  ('4572', 'CONTI'),
#  ('4572', 'INA'),
#  ('4589', 'BOSCH'),
#  ('4594', 'CONTINENTAL CTAM'),
#  ('4599', 'BOSCH'),
#  ('461', 'GATES'),
#  ('4621', 'DAYCO'),
#  ('4635', 'SKF'),
#  ('4642', 'FEBI BILSTEIN'),
#  ('4670', 'Volvo'),
#  ('4698', 'BOSCH'),
#  ('4709', 'Conti'),
#  ('4718', 'BOSCH'),
#  ('472', 'INA'),
#  ('4748', 'FEBI'),
#  ('4763', 'INA'),
#  ('4774', 'MEYLE'),
#  ('4778', 'SKF'),
#  ('4779', 'CONTI'),
#  ('4779', 'SKF'),
#  ('478', 'INA'),
#  ('4795', 'OPTIMAL'),
#  ('48', 'CONTINENTAL CTAM'),
#  ('4801', 'CONTI'),
#  ('4806', 'BOSCH'),
#  ('4809', 'CONTI'),
#  ('4809', 'INA'),
#  ('4811', 'GATES'),
#  ('4816', 'INA'),
#  ('4818', 'INA'),
#  ('4837', 'CONTI'),
#  ('4843', 'CONTI'),
#  ('4844', 'CONTINENTAL CTAM'),
#  ('4845', 'AKS'),
#  ('4845', 'DASIS'),
#  ('4857', 'CONTI'),
#  ('4863', 'FAI AutoParts'),
#  ('4874', 'SKF'),
#  ('4905', 'SKF'),
#  ('4906', 'CONTITECH'),
#  ('4913', 'CONTITECH'),
#  ('492', 'GATES'),
#  ('4920', 'SKF'),
#  ('4954', 'CONTITECH'),
#  ('4956', 'INA'),
#  ('497', '(Conti)'),
#  ('4975', 'INA'),
#  ('4982', 'DAYCO'),
#  ('4983', 'FAI AutoParts'),
#  ('4992', 'GATES'),
#  ('4994', 'FAI AutoParts'),
#  ('4995', 'CONTI'),
#  ('4995', 'FEBI'),
#  ('4998', 'FAI AutoParts'),
#  ('500', 'FEBI'),
#  ('519', 'GK'),
#  ('520', 'DAYCO'),
#  ('528', 'BOSCH'),
#  ('532', 'QUINTON HAZELL'),
#  ('533', 'BOSCH'),
#  ('547', 'BOSCH'),
#  ('547', 'FEBI'),
#  ('552', 'EXPERT KITS'),
#  ('552', 'VAICO'),
#  ('555', 'VDO'),
#  ('566', 'CONTI'),
#  ('569', 'CONTI'),
#  ('57', 'FAI'),
#  ('576', 'Conti'),
#  ('581', 'CONTITECH'),
#  ('590', 'CONTI'),
#  ('590', 'INA'),
#  ('620', 'FEBI'),
#  ('623', 'SWAG'),
#  ('668', 'FEBI BILSTEIN'),
#  ('689', 'FAI'),
#  ('695', 'INA'),
#  ('70', 'Conti CONTITECH'),
#  ('70', 'Conti Tech'),
#  ('710', 'CONTINENTAL CTAM'),
#  ('715', 'CONTINENTAL CTAM'),
#  ('719', 'GATES'),
#  ('728', 'INA'),
#  ('730', 'GATES'),
#  ('755', 'DAYCO'),
#  ('757', 'CONTI'),
#  ('757', 'FEBI'),
#  ('785', 'SKF'),
#  ('791', 'GATES'),
#  ('816', 'GATES'),
#  ('818', 'DAYCO'),
#  ('82', 'SKF'),
#  ('828', 'GATES'),
#  ('829', 'CONTINENTAL'),
#  ('832', 'BOSCH'),
#  ('835', 'CONTINENTAL'),
#  ('836', 'SKF'),
#  ('837', 'CONTINENTAL CTAM'),
#  ('850', 'BOSCH'),
#  ('850', 'SRC'),
#  ('883', 'SWAG'),
#  ('906', 'FEBI'),
#  ('91', 'SWAG'),
#  ('919', 'FEBI BILSTEIN'),
#  ('921', 'FEBI BILSTEIN'),
#  ('93', 'VAICO'),
#  ('934', 'CONTI'),
#  ('97', 'CONTI'),
#  ('989', 'CONTI'),
#  ('991', 'SKF'),
#  ('998', 'GATES')}

# %%
df_pred.aspect_name.unique()
# Out:
# array(['Hersteller', 'Modell', 'Produktart', 'Kompatible_Fahrzeug_Marke',
#        'Kompatibles_Fahrzeug_Modell', 'Einbauposition',
#        'Bremsscheiben-Aussendurchmesser', 'Im_Lieferumfang_Enthalten',
#        'Herstellernummer', 'Kompatibles_Fahrzeug_Jahr', 'SAE_Viskosität',
#        'Material', 'Bremsscheibenart', 'Stärke', 'Maßeinheit',
#        'Produktlinie', 'Anzahl_Der_Einheiten', 'Menge', 'Besonderheiten',
#        'Anwendung', 'Oe/Oem_Referenznummer(N)'], dtype=object)

# %%
df_target.aspect_name.unique()
# Out:
# array(['Hersteller', 'Modell', 'Produktart', 'Kompatible_Fahrzeug_Marke',
#        'Kompatibles_Fahrzeug_Modell', 'Einbauposition',
#        'Bremsscheiben-Aussendurchmesser', 'Im_Lieferumfang_Enthalten',
#        'Herstellernummer', 'Kompatibles_Fahrzeug_Jahr',
#        'Oe/Oem_Referenznummer(N)', 'Material', 'Größe',
#        'Bremsscheibenart', 'Stärke', 'Maßeinheit', 'Produktlinie',
#        'Anzahl_Der_Einheiten', 'Anwendung', 'Besonderheiten', 'Menge',
#        'Oberflächenbeschaffenheit', 'Technologie', 'Farbe',
#        'SAE_Viskosität'], dtype=object)

# %%
df_target.groupby('category').get_group('1')
# Out:
#      record_id category                  aspect_name            span
# 0            2        1                   Hersteller             ATE
# 1            2        1                       Modell      Power Disc
# 2            2        1                   Produktart      Bremsenset
# 3            2        1    Kompatible_Fahrzeug_Marke        Mercedes
# 4            2        1  Kompatibles_Fahrzeug_Modell             SLC
# ...        ...      ...                          ...             ...
# 7481      4972        1               Einbauposition           Vorne
# 7482      4972        1    Im_Lieferumfang_Enthalten          Beläge
# 7483      4972        1    Im_Lieferumfang_Enthalten        Scheiben
# 7484      4972        1    Kompatible_Fahrzeug_Marke           Skoda
# 7485      4972        1  Kompatibles_Fahrzeug_Modell  Fabia Roomster
#
# [4110 rows x 4 columns]

# %%
df_target.groupby('category').get_group('2')
# Out:
#      record_id category                aspect_name              span
# 10          17        2                 Hersteller  CONTINENTAL CTAM
# 11          17        2  Im_Lieferumfang_Enthalten       Wasserpumpe
# 12          17        2                 Produktart    Zahnriemensatz
# 13          17        2  Kompatible_Fahrzeug_Marke              OPEL
# 14          29        2                 Hersteller         CONTITECH
# ...        ...      ...                        ...               ...
# 7534      4995        2  Im_Lieferumfang_Enthalten        THERMOSTAT
# 7535      4998        2                 Hersteller     FAI AutoParts
# 7536      4998        2           Herstellernummer             TCK62
# 7537      4998        2  Im_Lieferumfang_Enthalten  Timing Chain Kit
# 7538      4998        2  Kompatible_Fahrzeug_Marke            SUZUKI
#
# [3429 rows x 4 columns]
