# %%
import pandas as pd

paths = ['tsvs/base_new_percentile_10.tsv',
    # 'tsvs/base_mod_word_spans_O_added_percentile_10_cleaned.tsv',
         'tsvs/base_new_percentile_20.tsv']

df0 = pd.read_csv(paths[0], sep='\t', names=['Record Number', 'Category', 'Aspect Name', 'Aspect Value']) 
df1 = pd.read_csv(paths[1], sep='\t', names=['Record Number', 'Category', 'Aspect Name', 'Aspect Value'])
# .to_csv('tsvs/base_mod_word_spans_O_added_percentile_10_cleaned.csv', index=False)

# %%
cat1 = df0.loc[df0['Category'] == 1]
cat2 = df1.loc[df1['Category'] == 2]

pd.concat([cat1, cat2]).to_csv('tsvs/base_new_10_20.tsv', index=False,
                               header=False, sep='\t')

# %%
df0
# Out:
#         Record Number  Category                Aspect Name      Aspect Value
# 0                5001         1  Kompatible_Fahrzeug_Marke              OPEL
# 1                5001         1       Anzahl_Der_Einheiten                 2
# 2                5001         1  Im_Lieferumfang_Enthalten     Bremsscheiben
# 3                5001         1       Anzahl_Der_Einheiten                 4
# 4                5001         1  Im_Lieferumfang_Enthalten            Beläge
# ...               ...       ...                        ...               ...
# 217438          30000         2                          O  Steuerkettensatz
# 217439          30000         2  Im_Lieferumfang_Enthalten       Steuerkette
# 217440          30000         2                 Produktart           RepSatz
# 217441          30000         2                 Produktart     Reparatursatz
# 217442          30000         2           Herstellernummer       559 0037 10
#
# [217443 rows x 4 columns]
